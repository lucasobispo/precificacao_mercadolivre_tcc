# %%
import boto3 as boto3
import pandas as pd
import pyarrow.parquet as pq
import s3fs
from io import BytesIO

# %%
pd.set_option('display.max_columns', 500)

# %%
ACCESS_KEY = 'ASIASEOMK5IL566ZFYXS'
SECRET_KEY = 'XtNtjeoHqSjMDuj6O/1R/+HnBQGGC9spYHearKEE'
AWS_SESSION_TOKEN = '...'

# %%
def pd_read_s3_parquet(key, bucket, s3_client=None, **args):
    if s3_client is None:
        s3_client = boto3.client('s3', aws_access_key_id=ACCESS_KEY,aws_secret_access_key=SECRET_KEY,aws_session_token=AWS_SESSION_TOKEN)
    obj = s3_client.get_object(Bucket=bucket, Key=key)
    return pd.read_parquet(BytesIO(obj['Body'].read()), **args)

# %%
def pd_read_s3_csv(my_bucket,my_file):
    s3 = boto3.client('s3', aws_access_key_id=ACCESS_KEY,
                      aws_secret_access_key=SECRET_KEY,
                      aws_session_token=AWS_SESSION_TOKEN)

    obj = s3.get_object(Bucket=my_bucket, Key= my_file)
    body =  pd.read_csv(obj['Body'])
    df = pd.DataFrame(body)
    return df

# %%
base_juntada_atributes =  pd_read_s3_parquet("20210505/dados-limpos-20210505.parquet","dados-transformados-mercadolivre")

# %%
#base_juntada_atributes.groupby('permalink').id.count().sort_values()
base_juntada_atributes
# Out:
#        Unnamed: 0             id site_id  \
# 0               0  MLB1783483197     MLB
# 1               0  MLB1783483197     MLB
# 2               0  MLB1783483197     MLB
# 3               0  MLB1783483197     MLB
# 4               1  MLB1784404609     MLB
# ...           ...            ...     ...
# 64926          69  MLB1791879583     MLB
# 64927          70  MLB1791880014     MLB
# 64928          71  MLB1791881723     MLB
# 64929          72  MLB1791882073     MLB
# 64930          73  MLB1791882761     MLB
#
#                                                              title   price  \
# 0      Xiaomi Redmi 9 (global) Dual Sim 64 Gb Carbon Grey 4 Gb Ram  1259.0
# 1      Xiaomi Redmi 9 (global) Dual Sim 64 Gb Carbon Grey 4 Gb Ram  1259.0
# 2      Xiaomi Redmi 9 (global) Dual Sim 64 Gb Carbon Grey 4 Gb Ram  1259.0
# 3      Xiaomi Redmi 9 (global) Dual Sim 64 Gb Carbon Grey 4 Gb Ram  1259.0
# 4         Xiaomi Redmi Note 8 Dual Sim 64 Gb Neptune Blue 4 Gb Ram  1355.0
# ...                                                            ...     ...
# 64926                                                    LG Bu200b    95.0
# 64927                               Celular Samsung Galaxy J2 Core    40.0
# 64928                               Smartphone Xiaomi Mi9 Se 128gb  1600.0
# 64929                                               iPhone 7 128gb  1500.0
# 64930                                  Samsung A01 32gb Octa Core    699.0
#
#        sale_price currency_id  available_quantity  sold_quantity buying_mode  \
# 0             NaN         BRL                  40              0  buy_it_now
# 1             NaN         BRL                  40              0  buy_it_now
# 2             NaN         BRL                  40              0  buy_it_now
# 3             NaN         BRL                  40              0  buy_it_now
# 4             NaN         BRL                  19             11  buy_it_now
# ...           ...         ...                 ...            ...         ...
# 64926         NaN         BRL                   1              0  buy_it_now
# 64927         NaN         BRL                   1              0  buy_it_now
# 64928         NaN         BRL                   1              0  buy_it_now
# 64929         NaN         BRL                   1              0  buy_it_now
# 64930         NaN         BRL                   1              0  buy_it_now
#
#       listing_type_id                 stop_time condition  \
# 0            gold_pro  2041-01-26T04:00:00.000Z       new
# 1            gold_pro  2041-01-26T04:00:00.000Z       new
# 2            gold_pro  2041-01-26T04:00:00.000Z       new
# 3            gold_pro  2041-01-26T04:00:00.000Z       new
# 4            gold_pro  2041-01-27T04:00:00.000Z       new
# ...               ...                       ...       ...
# 64926            free  2021-04-10T04:00:00.000Z      used
# 64927            free  2021-04-10T04:00:00.000Z      used
# 64928            free  2021-04-10T04:00:00.000Z      used
# 64929            free  2021-04-10T04:00:00.000Z      used
# 64930            free  2021-04-10T04:00:00.000Z       new
#
#                                                                                                      permalink  \
# 0      https://www.mercadolivre.com.br/xiaomi-redmi-9-global-dual-sim-64-gb-carbon-grey-4-gb-ram/p/MLB15949974
# 1      https://www.mercadolivre.com.br/xiaomi-redmi-9-global-dual-sim-64-gb-carbon-grey-4-gb-ram/p/MLB15949974
# 2      https://www.mercadolivre.com.br/xiaomi-redmi-9-global-dual-sim-64-gb-carbon-grey-4-gb-ram/p/MLB15949974
# 3      https://www.mercadolivre.com.br/xiaomi-redmi-9-global-dual-sim-64-gb-carbon-grey-4-gb-ram/p/MLB15949974
# 4       https://www.mercadolivre.com.br/xiaomi-redmi-note-8-dual-sim-64-gb-neptune-blue-4-gb-ram/p/MLB15188554
# ...                                                                                                        ...
# 64926                                         https://produto.mercadolivre.com.br/MLB-1791879583-lg-bu200b-_JM
# 64927                    https://produto.mercadolivre.com.br/MLB-1791880014-celular-samsung-galaxy-j2-core-_JM
# 64928                    https://produto.mercadolivre.com.br/MLB-1791881723-smartphone-xiaomi-mi9-se-128gb-_JM
# 64929                                    https://produto.mercadolivre.com.br/MLB-1791882073-iphone-7-128gb-_JM
# 64930                        https://produto.mercadolivre.com.br/MLB-1791882761-samsung-a01-32gb-octa-core-_JM
#
#                                                              thumbnail  \
# 0      http://mlb-s2-p.mlstatic.com/728273-MLA44516115670_012021-I.jpg
# 1      http://mlb-s2-p.mlstatic.com/728273-MLA44516115670_012021-I.jpg
# 2      http://mlb-s2-p.mlstatic.com/728273-MLA44516115670_012021-I.jpg
# 3      http://mlb-s2-p.mlstatic.com/728273-MLA44516115670_012021-I.jpg
# 4      http://mlb-s2-p.mlstatic.com/685606-MLA44528370861_012021-I.jpg
# ...                                                                ...
# 64926  http://mlb-s2-p.mlstatic.com/631887-MLB44845924014_022021-I.jpg
# 64927  http://mlb-s1-p.mlstatic.com/936116-MLB44845959031_022021-I.jpg
# 64928  http://mlb-s2-p.mlstatic.com/704141-MLB44845963133_022021-I.jpg
# 64929  http://mlb-s2-p.mlstatic.com/722433-MLB44845974230_022021-I.jpg
# 64930  http://mlb-s2-p.mlstatic.com/715387-MLA43775429216_102020-I.jpg
#
#                        thumbnail_id  accepts_mercadopago  \
# 0      728273-MLA44516115670_012021                 True
# 1      728273-MLA44516115670_012021                 True
# 2      728273-MLA44516115670_012021                 True
# 3      728273-MLA44516115670_012021                 True
# 4      685606-MLA44528370861_012021                 True
# ...                             ...                  ...
# 64926  631887-MLB44845924014_022021                 True
# 64927  936116-MLB44845959031_022021                 True
# 64928  704141-MLB44845963133_022021                 True
# 64929  722433-MLB44845974230_022021                 True
# 64930  715387-MLA43775429216_102020                 True
#
#                                                                                                                                                                                                                                                                                                         attributes  \
# 0      [{'id': 'BRAND', 'value_name': 'Xiaomi', 'value_struct': None, 'attribute_group_id': 'OTHERS', 'source': 1, 'name': 'Marca', 'value_id': '59387', 'values': [{'id': '59387', 'name': 'Xiaomi', 'struct': None, 'source': 1}], 'attribute_group_name': 'Outros'}, {'name': 'Modelo de GPU', 'value_id': '...
# 1      [{'id': 'BRAND', 'value_name': 'Xiaomi', 'value_struct': None, 'attribute_group_id': 'OTHERS', 'source': 1, 'name': 'Marca', 'value_id': '59387', 'values': [{'id': '59387', 'name': 'Xiaomi', 'struct': None, 'source': 1}], 'attribute_group_name': 'Outros'}, {'name': 'Modelo de GPU', 'value_id': '...
# 2      [{'id': 'BRAND', 'value_name': 'Xiaomi', 'value_struct': None, 'attribute_group_id': 'OTHERS', 'source': 1, 'name': 'Marca', 'value_id': '59387', 'values': [{'id': '59387', 'name': 'Xiaomi', 'struct': None, 'source': 1}], 'attribute_group_name': 'Outros'}, {'name': 'Modelo de GPU', 'value_id': '...
# 3      [{'id': 'BRAND', 'value_name': 'Xiaomi', 'value_struct': None, 'attribute_group_id': 'OTHERS', 'source': 1, 'name': 'Marca', 'value_id': '59387', 'values': [{'id': '59387', 'name': 'Xiaomi', 'struct': None, 'source': 1}], 'attribute_group_name': 'Outros'}, {'name': 'Modelo de GPU', 'value_id': '...
# 4      [{'attribute_group_name': 'Outros', 'id': 'BRAND', 'value_id': '59387', 'value_name': 'Xiaomi', 'value_struct': None, 'values': [{'source': 1, 'id': '59387', 'name': 'Xiaomi', 'struct': None}], 'attribute_group_id': 'OTHERS', 'source': 1, 'name': 'Marca'}, {'value_name': 'Adreno 610', 'values': ...
# ...                                                                                                                                                                                                                                                                                                            ...
# 64926  [{'value_struct': None, 'attribute_group_id': 'OTHERS', 'attribute_group_name': 'Outros', 'source': 6808261514773724, 'id': 'BRAND', 'name': 'Marca', 'value_id': '215', 'value_name': 'LG', 'values': [{'id': '215', 'name': 'LG', 'struct': None, 'source': 6808261514773724}]}, {'id': 'ITEM_CONDITIO...
# 64927  [{'id': 'BRAND', 'value_name': 'Samsung', 'value_struct': None, 'values': [{'id': '206', 'name': 'Samsung', 'struct': None, 'source': 7092}], 'source': 7092, 'name': 'Marca', 'value_id': '206', 'attribute_group_id': 'OTHERS', 'attribute_group_name': 'Outros'}, {'id': 'GPU_MODEL', 'value_id': '74...
# 64928  [{'name': 'Marca', 'value_id': '59387', 'attribute_group_id': 'OTHERS', 'attribute_group_name': 'Outros', 'source': 1, 'id': 'BRAND', 'value_name': 'Xiaomi', 'value_struct': None, 'values': [{'struct': None, 'source': 1, 'id': '59387', 'name': 'Xiaomi'}]}, {'id': 'ITEM_CONDITION', 'value_name': ...
# 64929  [{'source': 1505, 'value_name': 'Apple', 'attribute_group_id': 'OTHERS', 'value_id': '9344', 'value_struct': None, 'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1505}], 'attribute_group_name': 'Outros', 'id': 'BRAND', 'name': 'Marca'}, {'source': 1505, 'id': 'ITEM_CONDITIO...
# 64930  [{'name': 'Marca', 'source': 1, 'attribute_group_id': 'OTHERS', 'attribute_group_name': 'Outros', 'id': 'BRAND', 'value_id': '206', 'value_name': 'Samsung', 'value_struct': None, 'values': [{'id': '206', 'name': 'Samsung', 'struct': None, 'source': 1}]}, {'source': 1, 'name': 'Modelo de GPU', 'v...
#
#        original_price category_id  official_store_id       domain_id  \
# 0                 NaN     MLB1055                NaN  MLB-CELLPHONES
# 1                 NaN     MLB1055                NaN  MLB-CELLPHONES
# 2                 NaN     MLB1055                NaN  MLB-CELLPHONES
# 3                 NaN     MLB1055                NaN  MLB-CELLPHONES
# 4                 NaN     MLB1055                NaN  MLB-CELLPHONES
# ...               ...         ...                ...             ...
# 64926             NaN     MLB1055                NaN  MLB-CELLPHONES
# 64927             NaN     MLB1055                NaN  MLB-CELLPHONES
# 64928             NaN     MLB1055                NaN  MLB-CELLPHONES
# 64929             NaN     MLB1055                NaN  MLB-CELLPHONES
# 64930             NaN     MLB1055                NaN  MLB-CELLPHONES
#
#       catalog_product_id  \
# 0            MLB15949974
# 1            MLB15949974
# 2            MLB15949974
# 3            MLB15949974
# 4            MLB15188554
# ...                  ...
# 64926         MLB6000092
# 64927        MLB13799602
# 64928        MLB14482691
# 64929        MLB12866583
# 64930        MLB16107488
#
#                                                                                                                                                                                                tags  \
# 0      ['brand_verified', 'extended_warranty_eligible', 'good_quality_picture', 'good_quality_thumbnail', 'loyalty_discount_eligible', 'immediate_payment', 'cart_eligible', 'shipping_guaranteed']
# 1      ['brand_verified', 'extended_warranty_eligible', 'good_quality_picture', 'good_quality_thumbnail', 'loyalty_discount_eligible', 'immediate_payment', 'cart_eligible', 'shipping_guaranteed']
# 2      ['brand_verified', 'extended_warranty_eligible', 'good_quality_picture', 'good_quality_thumbnail', 'loyalty_discount_eligible', 'immediate_payment', 'cart_eligible', 'shipping_guaranteed']
# 3      ['brand_verified', 'extended_warranty_eligible', 'good_quality_picture', 'good_quality_thumbnail', 'loyalty_discount_eligible', 'immediate_payment', 'cart_eligible', 'shipping_guaranteed']
# 4       ['brand_verified', 'extended_warranty_eligible', 'good_quality_picture', 'loyalty_discount_eligible', 'immediate_payment', 'cart_eligible', 'shipping_guaranteed', 'best_seller_candidate']
# ...                                                                                                                                                                                             ...
# 64926                                                                                                                                 ['immediate_payment', 'cart_eligible', 'shipping_guaranteed']
# 64927                                                                                                                                                        ['immediate_payment', 'cart_eligible']
# 64928                                                                                                                                                        ['immediate_payment', 'cart_eligible']
# 64929                                                                                                                                                        ['immediate_payment', 'cart_eligible']
# 64930                                                                                                  ['good_quality_picture', 'incomplete_technical_specs', 'immediate_payment', 'cart_eligible']
#
#       catalog_listing  order_backend  seller.id  \
# 0                True              1  659765616
# 1                True              1  659765616
# 2                True              1  659765616
# 3                True              1  659765616
# 4                True              2  569953917
# ...               ...            ...        ...
# 64926            None             20   44502121
# 64927            None             21  323688771
# 64928            None             22  109069869
# 64929            None             23  606184398
# 64930            None             24  304056608
#
#                                                        seller.permalink  \
# 0      http://perfil.mercadolivre.com.br/OKINAWACOMERCIOOKINAWACOMERCIO
# 1      http://perfil.mercadolivre.com.br/OKINAWACOMERCIOOKINAWACOMERCIO
# 2      http://perfil.mercadolivre.com.br/OKINAWACOMERCIOOKINAWACOMERCIO
# 3      http://perfil.mercadolivre.com.br/OKINAWACOMERCIOOKINAWACOMERCIO
# 4                            http://perfil.mercadolivre.com.br/BIELAVIC
# ...                                                                 ...
# 64926                     http://perfil.mercadolivre.com.br/LUPERCIOS_1
# 64927                                                              None
# 64928         http://perfil.mercadolivre.com.br/YURISOUZAMARQUEZMARINHO
# 64929                     http://perfil.mercadolivre.com.br/CRNA2740544
# 64930                      http://perfil.mercadolivre.com.br/MODA377421
#
#             seller.registration_date  seller.car_dealer  \
# 0      2020-10-16T12:48:07.000-04:00              False
# 1      2020-10-16T12:48:07.000-04:00              False
# 2      2020-10-16T12:48:07.000-04:00              False
# 3      2020-10-16T12:48:07.000-04:00              False
# 4      2020-05-18T08:15:12.000-04:00              False
# ...                              ...                ...
# 64926  2008-02-02T18:12:26.000-04:00              False
# 64927                           None              False
# 64928  2012-04-12T01:45:52.000-04:00              False
# 64929  2020-07-08T18:37:16.000-04:00              False
# 64930  2018-02-24T08:43:06.000-04:00              False
#
#        seller.real_estate_agency  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 64926                      False
# 64927                      False
# 64928                      False
# 64929                      False
# 64930                      False
#
#                                                                               seller.tags  \
# 0                                                        ['normal', 'messages_as_seller']
# 1                                                        ['normal', 'messages_as_seller']
# 2                                                        ['normal', 'messages_as_seller']
# 3                                                        ['normal', 'messages_as_seller']
# 4                ['normal', 'credits_profile', 'messages_as_seller', 'messages_as_buyer']
# ...                                                                                   ...
# 64926  ['normal', 'mshops', 'credits_profile', 'messages_as_seller', 'messages_as_buyer']
# 64927                                                                                None
# 64928            ['normal', 'credits_profile', 'messages_as_seller', 'messages_as_buyer']
# 64929            ['normal', 'credits_profile', 'messages_as_seller', 'messages_as_buyer']
# 64930                               ['normal', 'messages_as_seller', 'messages_as_buyer']
#
#        seller.seller_reputation.transactions.total  \
# 0                                           1858.0
# 1                                           1858.0
# 2                                           1858.0
# 3                                           1858.0
# 4                                            396.0
# ...                                            ...
# 64926                                          9.0
# 64927                                          NaN
# 64928                                          3.0
# 64929                                          0.0
# 64930                                          0.0
#
#        seller.seller_reputation.transactions.canceled  \
# 0                                               105.0
# 1                                               105.0
# 2                                               105.0
# 3                                               105.0
# 4                                                37.0
# ...                                               ...
# 64926                                             0.0
# 64927                                             NaN
# 64928                                             0.0
# 64929                                             0.0
# 64930                                             0.0
#
#       seller.seller_reputation.transactions.period  \
# 0                                         historic
# 1                                         historic
# 2                                         historic
# 3                                         historic
# 4                                         historic
# ...                                            ...
# 64926                                     historic
# 64927                                         None
# 64928                                     historic
# 64929                                     historic
# 64930                                     historic
#
#        seller.seller_reputation.transactions.ratings.negative  \
# 0                                                        0.06
# 1                                                        0.06
# 2                                                        0.06
# 3                                                        0.06
# 4                                                        0.00
# ...                                                       ...
# 64926                                                    0.00
# 64927                                                     NaN
# 64928                                                    0.00
# 64929                                                    0.00
# 64930                                                    0.00
#
#        seller.seller_reputation.transactions.ratings.positive  \
# 0                                                        0.94
# 1                                                        0.94
# 2                                                        0.94
# 3                                                        0.94
# 4                                                        0.93
# ...                                                       ...
# 64926                                                    1.00
# 64927                                                     NaN
# 64928                                                    1.00
# 64929                                                    0.00
# 64930                                                    1.00
#
#        seller.seller_reputation.transactions.ratings.neutral  \
# 0                                                       0.00
# 1                                                       0.00
# 2                                                       0.00
# 3                                                       0.00
# 4                                                       0.07
# ...                                                      ...
# 64926                                                   0.00
# 64927                                                    NaN
# 64928                                                   0.00
# 64929                                                   0.00
# 64930                                                   0.00
#
#        seller.seller_reputation.transactions.completed  \
# 0                                               1753.0
# 1                                               1753.0
# 2                                               1753.0
# 3                                               1753.0
# 4                                                359.0
# ...                                                ...
# 64926                                              9.0
# 64927                                              NaN
# 64928                                              3.0
# 64929                                              0.0
# 64930                                              0.0
#
#       seller.seller_reputation.power_seller_status  \
# 0                                         platinum
# 1                                         platinum
# 2                                         platinum
# 3                                         platinum
# 4                                             None
# ...                                            ...
# 64926                                         None
# 64927                                         None
# 64928                                         None
# 64929                                         None
# 64930                                         None
#
#        seller.seller_reputation.metrics.claims.rate  \
# 0                                            0.0128
# 1                                            0.0128
# 2                                            0.0128
# 3                                            0.0128
# 4                                            0.0000
# ...                                             ...
# 64926                                        0.0000
# 64927                                           NaN
# 64928                                        0.0000
# 64929                                        0.0000
# 64930                                        0.0000
#
#        seller.seller_reputation.metrics.claims.value  \
# 0                                               21.0
# 1                                               21.0
# 2                                               21.0
# 3                                               21.0
# 4                                                1.0
# ...                                              ...
# 64926                                            0.0
# 64927                                            NaN
# 64928                                            0.0
# 64929                                            0.0
# 64930                                            0.0
#
#       seller.seller_reputation.metrics.claims.period  \
# 0                                            60 days
# 1                                            60 days
# 2                                            60 days
# 3                                            60 days
# 4                                            60 days
# ...                                              ...
# 64926                                       365 days
# 64927                                           None
# 64928                                       365 days
# 64929                                      60 months
# 64930                                       365 days
#
#        seller.seller_reputation.metrics.delayed_handling_time.rate  \
# 0                                                           0.0019
# 1                                                           0.0019
# 2                                                           0.0019
# 3                                                           0.0019
# 4                                                           0.1466
# ...                                                            ...
# 64926                                                       0.0000
# 64927                                                          NaN
# 64928                                                       0.0000
# 64929                                                       0.0000
# 64930                                                       0.0000
#
#        seller.seller_reputation.metrics.delayed_handling_time.value  \
# 0                                                               3.0
# 1                                                               3.0
# 2                                                               3.0
# 3                                                               3.0
# 4                                                              11.0
# ...                                                             ...
# 64926                                                           0.0
# 64927                                                           NaN
# 64928                                                           0.0
# 64929                                                           0.0
# 64930                                                           0.0
#
#       seller.seller_reputation.metrics.delayed_handling_time.period  \
# 0                                                           60 days
# 1                                                           60 days
# 2                                                           60 days
# 3                                                           60 days
# 4                                                           60 days
# ...                                                             ...
# 64926                                                      365 days
# 64927                                                          None
# 64928                                                      365 days
# 64929                                                     60 months
# 64930                                                      365 days
#
#       seller.seller_reputation.metrics.sales.period  \
# 0                                           60 days
# 1                                           60 days
# 2                                           60 days
# 3                                           60 days
# 4                                           60 days
# ...                                             ...
# 64926                                      365 days
# 64927                                          None
# 64928                                      365 days
# 64929                                     60 months
# 64930                                      365 days
#
#        seller.seller_reputation.metrics.sales.completed  \
# 0                                                1547.0
# 1                                                1547.0
# 2                                                1547.0
# 3                                                1547.0
# 4                                                  75.0
# ...                                                 ...
# 64926                                               9.0
# 64927                                               NaN
# 64928                                               3.0
# 64929                                               0.0
# 64930                                               0.0
#
#        seller.seller_reputation.metrics.cancellations.rate  \
# 0                                                   0.0024
# 1                                                   0.0024
# 2                                                   0.0024
# 3                                                   0.0024
# 4                                                   0.0000
# ...                                                    ...
# 64926                                               0.0000
# 64927                                                  NaN
# 64928                                               0.0000
# 64929                                               0.0000
# 64930                                               0.0000
#
#        seller.seller_reputation.metrics.cancellations.value  \
# 0                                                       4.0
# 1                                                       4.0
# 2                                                       4.0
# 3                                                       4.0
# 4                                                       0.0
# ...                                                     ...
# 64926                                                   0.0
# 64927                                                   NaN
# 64928                                                   0.0
# 64929                                                   0.0
# 64930                                                   0.0
#
#       seller.seller_reputation.metrics.cancellations.period  \
# 0                                                   60 days
# 1                                                   60 days
# 2                                                   60 days
# 3                                                   60 days
# 4                                                   60 days
# ...                                                     ...
# 64926                                              365 days
# 64927                                                  None
# 64928                                              365 days
# 64929                                             60 months
# 64930                                              365 days
#
#       seller.seller_reputation.level_id      prices.id  \
# 0                               5_green  MLB1783483197
# 1                               5_green  MLB1783483197
# 2                               5_green  MLB1783483197
# 3                               5_green  MLB1783483197
# 4                               5_green  MLB1784404609
# ...                                 ...            ...
# 64926                              None  MLB1791879583
# 64927                              None  MLB1791880014
# 64928                              None  MLB1791881723
# 64929                              None  MLB1791882073
# 64930                              None  MLB1791882761
#
#                                                                                                                                                                                                                                                                                          prices.prices  \
# 0      [{'id': '1', 'type': 'standard', 'conditions': {'context_restrictions': [], 'start_time': None, 'end_time': None, 'eligible': True}, 'amount': 1259, 'regular_amount': None, 'currency_id': 'BRL', 'exchange_rate_context': 'DEFAULT', 'metadata': {}, 'last_updated': '2021-02-01T02:15:07Z'}]
# 1      [{'id': '1', 'type': 'standard', 'conditions': {'context_restrictions': [], 'start_time': None, 'end_time': None, 'eligible': True}, 'amount': 1259, 'regular_amount': None, 'currency_id': 'BRL', 'exchange_rate_context': 'DEFAULT', 'metadata': {}, 'last_updated': '2021-02-01T02:15:07Z'}]
# 2      [{'id': '1', 'type': 'standard', 'conditions': {'context_restrictions': [], 'start_time': None, 'end_time': None, 'eligible': True}, 'amount': 1259, 'regular_amount': None, 'currency_id': 'BRL', 'exchange_rate_context': 'DEFAULT', 'metadata': {}, 'last_updated': '2021-02-01T02:15:07Z'}]
# 3      [{'id': '1', 'type': 'standard', 'conditions': {'context_restrictions': [], 'start_time': None, 'end_time': None, 'eligible': True}, 'amount': 1259, 'regular_amount': None, 'currency_id': 'BRL', 'exchange_rate_context': 'DEFAULT', 'metadata': {}, 'last_updated': '2021-02-01T02:15:07Z'}]
# 4      [{'id': '1', 'type': 'standard', 'conditions': {'context_restrictions': [], 'start_time': None, 'end_time': None, 'eligible': True}, 'amount': 1355, 'regular_amount': None, 'currency_id': 'BRL', 'exchange_rate_context': 'DEFAULT', 'metadata': {}, 'last_updated': '2021-02-01T22:48:03Z'}]
# ...                                                                                                                                                                                                                                                                                                ...
# 64926    [{'id': '1', 'type': 'standard', 'conditions': {'context_restrictions': [], 'start_time': None, 'end_time': None, 'eligible': True}, 'amount': 95, 'regular_amount': None, 'currency_id': 'BRL', 'exchange_rate_context': 'DEFAULT', 'metadata': {}, 'last_updated': '2021-02-09T13:21:55Z'}]
# 64927    [{'id': '2', 'type': 'standard', 'conditions': {'context_restrictions': [], 'start_time': None, 'end_time': None, 'eligible': True}, 'amount': 40, 'regular_amount': None, 'currency_id': 'BRL', 'exchange_rate_context': 'DEFAULT', 'metadata': {}, 'last_updated': '2021-02-09T13:29:05Z'}]
# 64928  [{'id': '1', 'type': 'standard', 'conditions': {'context_restrictions': [], 'start_time': None, 'end_time': None, 'eligible': True}, 'amount': 1600, 'regular_amount': None, 'currency_id': 'BRL', 'exchange_rate_context': 'DEFAULT', 'metadata': {}, 'last_updated': '2021-02-09T13:25:06Z'}]
# 64929  [{'id': '1', 'type': 'standard', 'conditions': {'context_restrictions': [], 'start_time': None, 'end_time': None, 'eligible': True}, 'amount': 1500, 'regular_amount': None, 'currency_id': 'BRL', 'exchange_rate_context': 'DEFAULT', 'metadata': {}, 'last_updated': '2021-02-09T13:25:23Z'}]
# 64930   [{'id': '1', 'type': 'standard', 'conditions': {'context_restrictions': [], 'start_time': None, 'end_time': None, 'eligible': True}, 'amount': 699, 'regular_amount': None, 'currency_id': 'BRL', 'exchange_rate_context': 'DEFAULT', 'metadata': {}, 'last_updated': '2021-02-09T13:22:45Z'}]
#
#       prices.presentation.display_currency prices.payment_method_prices  \
# 0                                      BRL                           []
# 1                                      BRL                           []
# 2                                      BRL                           []
# 3                                      BRL                           []
# 4                                      BRL                           []
# ...                                    ...                          ...
# 64926                                  BRL                           []
# 64927                                  BRL                           []
# 64928                                  BRL                           []
# 64929                                  BRL                           []
# 64930                                  BRL                           []
#
#        installments.quantity  installments.amount  installments.rate  \
# 0                       12.0               104.92               0.00
# 1                       12.0               104.92               0.00
# 2                       12.0               104.92               0.00
# 3                       12.0               104.92               0.00
# 4                       12.0               112.92               0.00
# ...                      ...                  ...                ...
# 64926                   12.0                 9.18              15.95
# 64927                    6.0                 7.43              11.39
# 64928                   12.0               154.60              15.95
# 64929                   12.0               144.94              15.95
# 64930                   12.0                67.54              15.95
#
#       installments.currency_id address.state_id  address.state_name  \
# 0                          BRL            BR-SP           São Paulo
# 1                          BRL            BR-SP           São Paulo
# 2                          BRL            BR-SP           São Paulo
# 3                          BRL            BR-SP           São Paulo
# 4                          BRL            BR-PR              Paraná
# ...                        ...              ...                 ...
# 64926                      BRL            BR-SP           São Paulo
# 64927                      BRL            BR-BA               Bahia
# 64928                      BRL            BR-MS  Mato Grosso do Sul
# 64929                      BRL            BR-SP           São Paulo
# 64930                      BRL            BR-SC      Santa Catarina
#
#            address.city_id address.city_name  shipping.free_shipping  \
# 0                 BR-SP-44         São Paulo                    True
# 1                 BR-SP-44         São Paulo                    True
# 2                 BR-SP-44         São Paulo                    True
# 3                 BR-SP-44         São Paulo                    True
# 4         TUxCQ1RFUjMwZTA0         Terra Boa                    True
# ...                    ...               ...                     ...
# 64926  QlItU1BHdWFwaWHDp3U          Guapiaçu                   False
# 64927     TUxCQ1NJTWUyMzlm      Simões Filho                   False
# 64928     TUxCQ0FOQTExZmQ1         Anastácio                    True
# 64929             BR-SP-96     Caraguatatuba                   False
# 64930     TUxCQ0lNQjE0NTNi          Imbituba                   False
#
#       shipping.mode                                   shipping.tags  \
# 0               me2  ['self_service_in', 'mandatory_free_shipping']
# 1               me2  ['self_service_in', 'mandatory_free_shipping']
# 2               me2  ['self_service_in', 'mandatory_free_shipping']
# 3               me2  ['self_service_in', 'mandatory_free_shipping']
# 4               me2                     ['mandatory_free_shipping']
# ...             ...                                             ...
# 64926           me2                                              []
# 64927           me2                                              []
# 64928           me2                                              []
# 64929           me2                                              []
# 64930           me2                                              []
#
#       shipping.logistic_type  shipping.store_pick_up  seller_address.id  \
# 0                xd_drop_off                   False                NaN
# 1                xd_drop_off                   False                NaN
# 2                xd_drop_off                   False                NaN
# 3                xd_drop_off                   False                NaN
# 4                   drop_off                   False                NaN
# ...                      ...                     ...                ...
# 64926               drop_off                   False                NaN
# 64927               drop_off                   False                NaN
# 64928               drop_off                   False                NaN
# 64929               drop_off                   False                NaN
# 64930               drop_off                   False                NaN
#
#        seller_address.comment  seller_address.address_line  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# ...                       ...                          ...
# 64926                     NaN                          NaN
# 64927                     NaN                          NaN
# 64928                     NaN                          NaN
# 64929                     NaN                          NaN
# 64930                     NaN                          NaN
#
#        seller_address.zip_code seller_address.country.id  \
# 0                          NaN                        BR
# 1                          NaN                        BR
# 2                          NaN                        BR
# 3                          NaN                        BR
# 4                          NaN                        BR
# ...                        ...                       ...
# 64926                      NaN                        BR
# 64927                      NaN                        BR
# 64928                      NaN                        BR
# 64929                      NaN                        BR
# 64930                      NaN                        BR
#
#       seller_address.country.name seller_address.state.id  \
# 0                          Brasil                   BR-SP
# 1                          Brasil                   BR-SP
# 2                          Brasil                   BR-SP
# 3                          Brasil                   BR-SP
# 4                          Brasil                   BR-PR
# ...                           ...                     ...
# 64926                      Brasil                   BR-SP
# 64927                      Brasil                   BR-BA
# 64928                      Brasil                   BR-MS
# 64929                      Brasil                   BR-SP
# 64930                      Brasil                   BR-SC
#
#       seller_address.state.name seller_address.city.id  \
# 0                     São Paulo               BR-SP-44
# 1                     São Paulo               BR-SP-44
# 2                     São Paulo               BR-SP-44
# 3                     São Paulo               BR-SP-44
# 4                        Paraná       TUxCQ1RFUjMwZTA0
# ...                         ...                    ...
# 64926                 São Paulo    QlItU1BHdWFwaWHDp3U
# 64927                     Bahia       TUxCQ1NJTWUyMzlm
# 64928        Mato Grosso do Sul       TUxCQ0FOQTExZmQ1
# 64929                 São Paulo               BR-SP-96
# 64930            Santa Catarina       TUxCQ0lNQjE0NTNi
#
#       seller_address.city.name  seller_address.latitude  \
# 0                    São Paulo                      NaN
# 1                    São Paulo                      NaN
# 2                    São Paulo                      NaN
# 3                    São Paulo                      NaN
# 4                    Terra Boa                      NaN
# ...                        ...                      ...
# 64926                 Guapiaçu                      NaN
# 64927             Simões Filho                      NaN
# 64928                Anastácio                      NaN
# 64929            Caraguatatuba                      NaN
# 64930                 Imbituba                      NaN
#
#        seller_address.longitude  differential_pricing.id  \
# 0                           NaN               33580182.0
# 1                           NaN               33580182.0
# 2                           NaN               33580182.0
# 3                           NaN               33580182.0
# 4                           NaN               33580182.0
# ...                         ...                      ...
# 64926                       NaN               33426180.0
# 64927                       NaN               33426180.0
# 64928                       NaN               33426180.0
# 64929                       NaN               33426180.0
# 64930                       NaN               33426180.0
#
#        seller.seller_reputation.metrics.claims.excluded.real_rate  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ...                                                           ...
# 64926                                                         NaN
# 64927                                                         NaN
# 64928                                                         NaN
# 64929                                                         NaN
# 64930                                                         NaN
#
#        seller.seller_reputation.metrics.claims.excluded.real_value  \
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# ...                                                            ...
# 64926                                                          NaN
# 64927                                                          NaN
# 64928                                                          NaN
# 64929                                                          NaN
# 64930                                                          NaN
#
#        seller.seller_reputation.metrics.delayed_handling_time.excluded.real_rate  \
# 0                                                                            NaN
# 1                                                                            NaN
# 2                                                                            NaN
# 3                                                                            NaN
# 4                                                                            NaN
# ...                                                                          ...
# 64926                                                                        NaN
# 64927                                                                        NaN
# 64928                                                                        NaN
# 64929                                                                        NaN
# 64930                                                                        NaN
#
#        seller.seller_reputation.metrics.delayed_handling_time.excluded.real_value  \
# 0                                                                             NaN
# 1                                                                             NaN
# 2                                                                             NaN
# ...
# 64928                                                                 NaN
# 64929                                                                 NaN
# 64930                                                                 NaN
#
#       seller.seller_reputation.protection_end_date  \
# 0                                             None
# 1                                             None
# 2                                             None
# 3                                             None
# 4                                             None
# ...                                            ...
# 64926                                         None
# 64927                                         None
# 64928                                         None
# 64929                                         None
# 64930                                         None
#
#       seller.seller_reputation.real_level seller.eshop.nick_name  \
# 0                                    None                   None
# 1                                    None                   None
# 2                                    None                   None
# 3                                    None                   None
# 4                                    None                   None
# ...                                   ...                    ...
# 64926                                None                   None
# 64927                                None                   None
# 64928                                None                   None
# 64929                                None                   None
# 64930                                None                   None
#
#        seller.eshop.eshop_rubro  seller.eshop.eshop_id  \
# 0                           NaN                    NaN
# 1                           NaN                    NaN
# 2                           NaN                    NaN
# 3                           NaN                    NaN
# 4                           NaN                    NaN
# ...                         ...                    ...
# 64926                       NaN                    NaN
# 64927                       NaN                    NaN
# 64928                       NaN                    NaN
# 64929                       NaN                    NaN
# 64930                       NaN                    NaN
#
#       seller.eshop.eshop_locations seller.eshop.site_id  \
# 0                             None                 None
# 1                             None                 None
# 2                             None                 None
# 3                             None                 None
# 4                             None                 None
# ...                            ...                  ...
# 64926                         None                 None
# 64927                         None                 None
# 64928                         None                 None
# 64929                         None                 None
# 64930                         None                 None
#
#       seller.eshop.eshop_logo_url  seller.eshop.eshop_status_id  \
# 0                            None                           NaN
# 1                            None                           NaN
# 2                            None                           NaN
# 3                            None                           NaN
# 4                            None                           NaN
# ...                           ...                           ...
# 64926                        None                           NaN
# 64927                        None                           NaN
# 64928                        None                           NaN
# 64929                        None                           NaN
# 64930                        None                           NaN
#
#        seller.eshop.seller  seller.eshop.eshop_experience  installments  \
# 0                      NaN                            NaN           NaN
# 1                      NaN                            NaN           NaN
# 2                      NaN                            NaN           NaN
# 3                      NaN                            NaN           NaN
# 4                      NaN                            NaN           NaN
# ...                    ...                            ...           ...
# 64926                  NaN                            NaN           NaN
# 64927                  NaN                            NaN           NaN
# 64928                  NaN                            NaN           NaN
# 64929                  NaN                            NaN           NaN
# 64930                  NaN                            NaN           NaN
#
#       date_file category_file prices.reference_prices seller.car_dealer_logo  \
# 0      20210202       MLB1051                    None                   None
# 1      20210202       MLB1051                    None                   None
# 2      20210202       MLB1055                    None                   None
# 3      20210202       MLB1055                    None                   None
# 4      20210202       MLB1051                    None                   None
# ...         ...           ...                     ...                    ...
# 64926  20210210       MLB1055                    None                   None
# 64927  20210210       MLB1055                    None                   None
# 64928  20210210       MLB1055                    None                   None
# 64929  20210210       MLB1055                    None                   None
# 64930  20210210       MLB1055                    None                   None
#
#       use_thumbnail_id prices.purchase_discounts prices.prices.type  \
# 0                 None                      None           standard
# 1                 None                      None           standard
# 2                 None                      None           standard
# 3                 None                      None           standard
# 4                 None                      None           standard
# ...                ...                       ...                ...
# 64926             None                      None           standard
# 64927             None                      None           standard
# 64928             None                      None           standard
# 64929             None                      None           standard
# 64930             None                      None           standard
#
#       prices.prices.last_updated    Marca   Modelo de GPU Condição do item  \
# 0           2021-02-01T02:15:07Z   Xiaomi    Mali-G52 MC2             Novo
# 1           2021-02-01T02:15:07Z   Xiaomi    Mali-G52 MC2             Novo
# 2           2021-02-01T02:15:07Z   Xiaomi    Mali-G52 MC2             Novo
# 3           2021-02-01T02:15:07Z   Xiaomi    Mali-G52 MC2             Novo
# 4           2021-02-01T22:48:03Z   Xiaomi      Adreno 610             Novo
# ...                          ...      ...             ...              ...
# 64926       2021-02-09T13:21:55Z       LG  PowerVR GT7600            Usado
# 64927       2021-02-09T13:29:05Z  Samsung   Mali-T720 MP2            Usado
# 64928       2021-02-09T13:25:06Z   Xiaomi   Mali-T720 MP2            Usado
# 64929       2021-02-09T13:25:23Z    Apple   Mali-T720 MP2            Usado
# 64930       2021-02-09T13:22:45Z  Samsung  PowerVR GE8100             Novo
#
#           Linha         Modelo Modelo do processador   Peso Modelo detalhado  \
# 0         Redmi     9 (Global)    MediaTek Helio G80  198 g             None
# 1         Redmi     9 (Global)    MediaTek Helio G80  198 g            P9089
# 2         Redmi     9 (Global)    MediaTek Helio G80  198 g             None
# 3         Redmi     9 (Global)    MediaTek Helio G80  198 g            P9089
# 4         Redmi         Note 8        Snapdragon 665  190 g             None
# ...         ...            ...                   ...    ...              ...
# 64926                    GU200              Apple A9  196 g            P9106
# 64927  Galaxy J        J2 Core           Exynos 7570  154 g            P9106
# 64928        Mi           9 SE        Snapdragon 712  155 g            P9106
# 64929    iPhone       iPhone 7      Apple A12 Bionic  177 g            P9106
# 64930  Galaxy A  A01 Core Duos       Mediatek MT6739  150 g            P9106
#
#       Modelo alfanumérico Marca da película Modelo da película  \
# 0                    None              None               None
# 1             GH59-15063A                               iPhone
# 2                    None              None               None
# 3             GH59-15063A                               iPhone
# 4                    None              None               None
# ...                   ...               ...                ...
# 64926            XMSH11HM            Hprime    Vidro Temperado
# 64927            XMSH11HM            Hprime    Vidro Temperado
# 64928            XMSH11HM            Hprime    Vidro Temperado
# 64929            XMSH11HM            Hprime    Vidro Temperado
# 64930            XMSH11HM            Hprime    Vidro Temperado
#
#       Unidades por embalagem Marca compatível Linha compatível  \
# 0                       None             None             None
# 1                          1           Philco              Q10
# 2                       None             None             None
# 3                          1           Philco              Q10
# 4                       None             None             None
# ...                      ...              ...              ...
# 64926                      1           Xiaomi               MI
# 64927                      1           Xiaomi               MI
# 64928                      1           Xiaomi               MI
# 64929                      1           Xiaomi               MI
# 64930                      1           Xiaomi               MI
#
#       Modelo compatível Marca do cabo Comprimento do cabo Modelo do cabo  \
# 0                  None          None                None           None
# 1           Worktab Q10  FFU / Marjay                 2 m      Magnético
# 2                  None          None                None           None
# 3           Worktab Q10  FFU / Marjay                 2 m      Magnético
# 4                  None          None                None           None
# ...                 ...           ...                 ...            ...
# 64926             MI A3      Inovação               1.8 m          PS-30
# 64927             MI A3      Inovação               1.8 m          PS-30
# 64928             MI A3      Inovação               1.8 m          PS-30
# 64929             MI A3      Inovação               1.8 m          PS-30
# 64930             MI A3      Inovação               1.8 m          PS-30
#
#       Marca do celular Linha do celular        Modelo do celular  \
# 0                 None             None                     None
# 1                 Sony           iPhone                       C4
# 2                 None             None                     None
# 3                 Sony           iPhone                       C4
# 4                 None             None                     None
# ...                ...              ...                      ...
# 64926                            iPhone  Compativel com iphone X
# 64927                            iPhone  Compativel com iphone X
# 64928                            iPhone  Compativel com iphone X
# 64929                            iPhone  Compativel com iphone X
# 64930                            iPhone  Compativel com iphone X
#
#       Marca da Capa Marca de Celular Modelo de Celular Modelo da Capa  \
# 0              None             None              None           None
# 1                              Apple            iPhone         iPhone
# 2              None             None              None           None
# 3                              Apple            iPhone         iPhone
# 4              None             None              None           None
# ...             ...              ...               ...            ...
# 64926       Clevisa           Xiaomi      Redmi Note 9      Aveludada
# 64927       Clevisa           Xiaomi      Redmi Note 9      Aveludada
# 64928       Clevisa           Xiaomi      Redmi Note 9      Aveludada
# 64929       Clevisa           Xiaomi      Redmi Note 9      Aveludada
# 64930       Clevisa           Xiaomi      Redmi Note 9      Aveludada
#
#       Marca da bateria Modelo da bateria Comprimento da pulseira Comprimento  \
# 0                 None              None                    None        None
# 1           Multilaser            MLB502            120mm x 87mm       56 mm
# 2                 None              None                    None        None
# 3           Multilaser            MLB502            120mm x 87mm       56 mm
# 4                 None              None                    None        None
# ...                ...               ...                     ...         ...
# 64926         Motorola              JE40            120mm x 87mm       10 cm
# 64927         Motorola              JE40            120mm x 87mm       10 cm
# 64928         Motorola              JE40            120mm x 87mm       10 cm
# 64929         Motorola              JE40            120mm x 87mm       10 cm
# 64930         Motorola              JE40            120mm x 87mm       10 cm
#
#       Marca de celular compatível Comprimento da embalagem Peso da embalagem  \
# 0                            None                     None              None
# 1                       Universal                     4 cm          0.127 kg
# 2                            None                     None              None
# 3                       Universal                     4 cm          0.127 kg
# 4                            None                     None              None
# ...                           ...                      ...               ...
# 64926                                                35 cm             265 g
# 64927                                                35 cm             265 g
# 64928                                                35 cm             265 g
# 64929                                                35 cm             265 g
# 64930                                                35 cm             265 g
#
#       Potência                                                  title_upper  \
# 0         None  XIAOMI REDMI 9 (GLOBAL) DUAL SIM 64 GB CARBON GREY 4 GB RAM
# 1         None  XIAOMI REDMI 9 (GLOBAL) DUAL SIM 64 GB CARBON GREY 4 GB RAM
# 2         None  XIAOMI REDMI 9 (GLOBAL) DUAL SIM 64 GB CARBON GREY 4 GB RAM
# 3         None  XIAOMI REDMI 9 (GLOBAL) DUAL SIM 64 GB CARBON GREY 4 GB RAM
# 4         None     XIAOMI REDMI NOTE 8 DUAL SIM 64 GB NEPTUNE BLUE 4 GB RAM
# ...        ...                                                          ...
# 64926                                                             LG BU200B
# 64927                                        CELULAR SAMSUNG GALAXY J2 CORE
# 64928                                        SMARTPHONE XIAOMI MI9 SE 128GB
# 64929                                                        IPHONE 7 128GB
# 64930                                           SAMSUNG A01 32GB OCTA CORE
#
#       memory ram_memory
# 0         64          4
# 1         64          4
# 2         64          4
# 3         64          4
# 4         64          4
# ...      ...        ...
# 64926   None       None
# 64927   None       None
# 64928   None       None
# 64929   None       None
# 64930   None       None
#
# [64931 rows x 144 columns]

# %% [markdown]
# #Tratamento das colunas

# %%
from flatten_json import (check_if_numbers_are_consecutive, cli, flatten,
                          flatten_preserve_lists, unflatten, unflatten_list)
import pandas as pd
import urllib.request as urllib2
import json
import re

base_juntada_atributes['title_upper'] = base_juntada_atributes['title'].str.upper()

GB_search = []
GBRAM_search = []
for values in base_juntada_atributes['title_upper']:
    
    if re.findall(r"(\d+) GB(?!RAM|\.).*", values):
        GB_search.append(*re.findall(r"(\d+) GB(?!RAM|\.).*", values))
    else:
        GB_search.append(None)
    
    if re.findall(r"(\d+) GB RAM", values):
        GBRAM_search.append(*re.findall(r"(\d+) GB RAM", values))
    else:
        GBRAM_search.append(None)
    
#     print(values)
#     print(*GB_search)
base_juntada_atributes['memory'] = GB_search
base_juntada_atributes['ram_memory'] = GBRAM_search

# %%
#Função de calssificação do titulo
def classifica_titulo(titulo):
    for key in keywords:
        if titulo.upper().find(key) > -1:
            return key
    return 'CELULAR'

# %%
#Remoção das linhas duplicadas
lista_marcas = ['Apple','Xiaomi', 'Realme', 'Motorola', 'Samsung', 'Sony', 'LG', 'Huawei']
without_duplicates = base_juntada_atributes.drop_duplicates()
without_duplicates_permalink =  without_duplicates.drop_duplicates(subset = 'permalink', keep = 'first')
df_marcas= without_duplicates_permalink[without_duplicates_permalink.Marca.isin(lista_marcas)]

# %%
keywords=['CAPA', 'RELOGIO', 'CAPINHA', 'XIAOMI POCO M3', 'MOTO G9 PLUS DUAL SIM 128 GB AZUL-ÍNDIGO 4 GB RAM', 'WATCH']
df_marcas['classificacao']=df_marcas['title_upper'].apply(classifica_titulo)
# Out:
# C:\Users\eloah.noguchi\Miniconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_marcas_classificacao = df_marcas[df_marcas.classificacao == 'CELULAR']

# %%
df_marcas_classificacao['modelo_upper'] = df_marcas_classificacao['Modelo'].str.upper()
# Out:
# C:\Users\eloah.noguchi\Miniconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_marcas_classificacao
# Out:
#         Unnamed: 0             id site_id  \
# 0                0  MLB1811830647     MLB
# 4                1  MLB1811696357     MLB
# 8                2  MLB1810714496     MLB
# 12               3  MLB1811760957     MLB
# 16               4  MLB1811384403     MLB
# ...            ...            ...     ...
# 860461         958  MLB1874618971     MLB
# 860462         959  MLB1874618993     MLB
# 860463         960  MLB1874618999     MLB
# 860464         961  MLB1874622607     MLB
# 860465         962  MLB1874622609     MLB
#
#                                                     title    price  \
# 0        Samsung Galaxy M31 Dual Sim 128 Gb Azul 6 Gb Ram  1989.00
# 4       Xiaomi Redmi 9 (india) Dual Sim 64 Gb Sky Blue...  1119.00
# 8       Samsung Galaxy A10s Dual Sim 32 Gb Vermelho 2 ...   864.00
# 12      Xiaomi Redmi Note 8 Dual Sim 64 Gb Space Black...  1170.50
# 16      Xiaomi Redmi Note 9 Pro (48 Mpx) Dual Sim 128 ...  1680.00
# ...                                                   ...      ...
# 860461  Smartphone Motorola Moto G10 Xt2127-2 Dual Sim...  1459.50
# 860462  Smartphone Motorola Moto G10 Xt2127-2 Dual Sim...  1399.50
# 860463  Celular Motorola Moto G10 Xt2127-2 Dual Sim 64...  1399.85
# 860464  Smartphone Motorola Moto G10 Dual Sim 64gb Cin...  1399.00
# 860465  Smartphone Motorola Moto G10 Xt2127-2 Dual Sim...  1329.15
#
#         sale_price currency_id  available_quantity  sold_quantity buying_mode  \
# 0              NaN         BRL                 100              0  buy_it_now
# 4              NaN         BRL                  18              2  buy_it_now
# 8              NaN         BRL                 149             17  buy_it_now
# 12             NaN         BRL                   3              1  buy_it_now
# 16             NaN         BRL                   1              7  buy_it_now
# ...            ...         ...                 ...            ...         ...
# 860461         NaN         BRL                   1              0  buy_it_now
# 860462         NaN         BRL                   1              0  buy_it_now
# 860463         NaN         BRL                   1              2  buy_it_now
# 860464         NaN         BRL                   1              0  buy_it_now
# 860465         NaN         BRL                   1              0  buy_it_now
#
#        listing_type_id                 stop_time condition  \
# 0         gold_special  2041-02-24T04:00:00.000Z       new
# 4             gold_pro  2041-02-24T04:00:00.000Z       new
# 8             gold_pro  2041-02-24T04:00:00.000Z       new
# 12        gold_special  2041-02-24T04:00:00.000Z       new
# 16            gold_pro  2041-02-24T04:00:00.000Z       new
# ...                ...                       ...       ...
# 860461        gold_pro  2041-04-29T04:00:00.000Z       new
# 860462        gold_pro  2041-04-29T04:00:00.000Z       new
# 860463        gold_pro  2041-04-29T04:00:00.000Z       new
# 860464        gold_pro  2041-04-29T04:00:00.000Z       new
# 860465    gold_special  2041-04-29T04:00:00.000Z       new
#
#                                                 permalink  \
# 0       https://www.mercadolivre.com.br/samsung-galaxy...
# 4       https://www.mercadolivre.com.br/xiaomi-redmi-9...
# 8       https://www.mercadolivre.com.br/samsung-galaxy...
# 12      https://www.mercadolivre.com.br/xiaomi-redmi-n...
# 16      https://www.mercadolivre.com.br/xiaomi-redmi-n...
# ...                                                   ...
# 860461  https://produto.mercadolivre.com.br/MLB-187461...
# 860462  https://produto.mercadolivre.com.br/MLB-187461...
# 860463  https://produto.mercadolivre.com.br/MLB-187461...
# 860464  https://produto.mercadolivre.com.br/MLB-187462...
# 860465  https://produto.mercadolivre.com.br/MLB-187462...
#
#                                                 thumbnail  \
# 0       http://mlb-s2-p.mlstatic.com/767423-MLA4378673...
# 4       http://mlb-s2-p.mlstatic.com/910320-MLA4501708...
# 8       http://mlb-s1-p.mlstatic.com/959533-MLA4303536...
# 12      http://mlb-s2-p.mlstatic.com/654642-MLA4452837...
# 16      http://http2.mlstatic.com/D_815080-MLA44387589...
# ...                                                   ...
# 860461  http://http2.mlstatic.com/D_703719-MLB45813257...
# 860462  http://http2.mlstatic.com/D_874391-MLB45813258...
# 860463  http://http2.mlstatic.com/D_980032-MLB45813262...
# 860464  http://http2.mlstatic.com/D_974160-MLB45813254...
# 860465  http://http2.mlstatic.com/D_642839-MLB45813256...
#
#                         thumbnail_id  accepts_mercadopago  \
# 0       767423-MLA43786733092_102020                 True
# 4       910320-MLA45017083929_022021                 True
# 8       959533-MLA43035365270_082020                 True
# 12      654642-MLA44528370852_012021                 True
# 16      815080-MLA44387589844_122020                 True
# ...                              ...                  ...
# 860461  703719-MLB45813257484_052021                 True
# 860462  874391-MLB45813258387_052021                 True
# 860463  980032-MLB45813262022_052021                 True
# 860464  974160-MLB45813254998_052021                 True
# 860465  642839-MLB45813256640_052021                 True
#
#                                                attributes  original_price  \
# 0       [{'id': 'BRAND', 'value_id': '206', 'attribute...             NaN
# 4       [{'value_id': '59387', 'value_struct': None, '...             NaN
# 8       [{'name': 'Marca', 'value_id': '206', 'values'...             NaN
# 12      [{'attribute_group_name': 'Outros', 'value_id'...             NaN
# 16      [{'value_name': 'Xiaomi', 'values': [{'source'...             NaN
# ...                                                   ...             ...
# 860461  [{'attribute_group_id': 'OTHERS', 'value_name'...             NaN
# 860462  [{'attribute_group_name': 'Outros', 'source': ...             NaN
# 860463  [{'attribute_group_id': 'OTHERS', 'attribute_g...             NaN
# 860464  [{'value_struct': None, 'values': [{'id': '250...             NaN
# 860465  [{'id': 'BRAND', 'attribute_group_name': 'Outr...             NaN
#
#        category_id  official_store_id       domain_id catalog_product_id  \
# 0          MLB1055                NaN  MLB-CELLPHONES        MLB15591543
# 4          MLB1055                NaN  MLB-CELLPHONES        MLB17338099
# 8          MLB1055                NaN  MLB-CELLPHONES        MLB15157295
# 12         MLB1055                NaN  MLB-CELLPHONES        MLB15188552
# 16         MLB1055                NaN  MLB-CELLPHONES        MLB16522550
# ...            ...                ...             ...                ...
# 860461     MLB1055                NaN  MLB-CELLPHONES        MLB17402147
# 860462     MLB1055                NaN  MLB-CELLPHONES        MLB17402147
# 860463     MLB1055                NaN  MLB-CELLPHONES        MLB17402147
# 860464     MLB1055                NaN  MLB-CELLPHONES        MLB17402147
# 860465     MLB1055                NaN  MLB-CELLPHONES        MLB17402147
#
#                                                      tags catalog_listing  \
# 0       ['extended_warranty_eligible', 'good_quality_p...            True
# 4       ['extended_warranty_eligible', 'good_quality_p...            True
# 8       ['good_quality_thumbnail', 'loyalty_discount_e...            True
# 12      ['extended_warranty_eligible', 'good_quality_p...            True
# 16      ['extended_warranty_eligible', 'good_quality_p...            True
# ...                                                   ...             ...
# 860461  ['catalog_product_candidate', 'extended_warran...            None
# 860462  ['extended_warranty_eligible', 'good_quality_p...            None
# 860463  ['catalog_product_candidate', 'extended_warran...            None
# 860464  ['extended_warranty_eligible', 'good_quality_p...            None
# 860465  ['catalog_product_candidate', 'extended_warran...            None
#
#         use_thumbnail_id  order_backend  seller.id  \
# 0                   True              1   67371102
# 4                   True              2  567262499
# 8                   True              3   34743206
# 12                  True              4   19588869
# 16                  True              5  517300660
# ...                  ...            ...        ...
# 860461             False             32  535500503
# 860462             False             33  535547262
# 860463             False             34  699699280
# 860464             False             35  212266509
# 860465             False             36  535485382
#
#                                          seller.permalink  \
# 0       http://perfil.mercadolivre.com.br/MACIELMATHEUS39
# 4        http://perfil.mercadolivre.com.br/DAVIELECTRO+02
# 8       http://perfil.mercadolivre.com.br/EVB+ELETR%C3...
# 12      http://perfil.mercadolivre.com.br/ALUK+IMPORTADOS
# 16              http://perfil.mercadolivre.com.br/GP+GAME
# ...                                                   ...
# 860461      http://perfil.mercadolivre.com.br/FONEWEB2020
# 860462  http://perfil.mercadolivre.com.br/MONARA+COMER...
# 860463  http://perfil.mercadolivre.com.br/COMERCIALBRA...
# 860464  http://perfil.mercadolivre.com.br/BUMPERMAGAZINEE
# 860465    http://perfil.mercadolivre.com.br/STOK+MAGAZINE
#
#              seller.registration_date  seller.car_dealer  \
# 0       2011-08-19T19:43:58.000-04:00              False
# 4       2020-05-12T17:48:42.000-04:00              False
# 8       2010-10-08T05:25:55.000-04:00              False
# 12      2007-06-15T09:38:35.000-04:00              False
# 16      2020-01-22T12:10:03.000-04:00              False
# ...                               ...                ...
# 860461  2020-03-12T10:53:34.000-04:00              False
# 860462  2020-03-12T13:39:35.000-04:00              False
# 860463  2021-01-10T14:03:09.000-04:00              False
# 860464  2016-04-25T15:14:12.000-04:00              False
# 860465  2020-03-12T10:15:46.000-04:00              False
#
#         seller.real_estate_agency  \
# 0                           False
# 4                           False
# 8                           False
# 12                          False
# 16                          False
# ...                           ...
# 860461                      False
# 860462                      False
# 860463                      False
# 860464                      False
# 860465                      False
#
#                                               seller.tags  \
# 0       ['normal', 'credits_profile', 'messages_as_sel...
# 4       ['normal', 'credits_profile', 'messages_as_sel...
# 8       ['normal', 'eshop', 'mshops', 'messages_as_sel...
# 12      ['normal', 'eshop', 'mshops', 'messages_as_sel...
# 16      ['normal', 'mshops', 'messages_as_seller', 'me...
# ...                                                   ...
# 860461  ['normal', 'messages_as_seller', 'messages_as_...
# 860462  ['normal', 'messages_as_seller', 'messages_as_...
# 860463  ['normal', 'credits_profile', 'messages_as_sel...
# 860464  ['normal', 'credits_profile', 'messages_as_sel...
# 860465  ['normal', 'messages_as_seller', 'messages_as_...
#
#         seller.seller_reputation.transactions.total  \
# 0                                              31.0
# 4                                            2031.0
# 8                                           19698.0
# 12                                           1102.0
# 16                                           4673.0
# ...                                             ...
# 860461                                        161.0
# 860462                                      16478.0
# 860463                                       1085.0
# 860464                                       8423.0
# 860465                                       2426.0
#
#         seller.seller_reputation.transactions.canceled  \
# 0                                                  7.0
# 4                                                112.0
# 8                                                989.0
# 12                                                90.0
# 16                                               356.0
# ...                                                ...
# 860461                                            22.0
# 860462                                          1035.0
# 860463                                            96.0
# 860464                                           613.0
# 860465                                           151.0
#
#        seller.seller_reputation.transactions.period  \
# 0                                          historic
# 4                                          historic
# 8                                          historic
# 12                                         historic
# 16                                         historic
# ...                                             ...
# 860461                                     historic
# 860462                                     historic
# 860463                                     historic
# 860464                                     historic
# 860465                                     historic
#
#         seller.seller_reputation.transactions.ratings.negative  \
# 0                                                    0.52
# 4                                                    0.01
# 8                                                    0.04
# 12                                                   0.00
# 16                                                   0.01
# ...                                                   ...
# 860461                                               0.00
# 860462                                               0.07
# 860463                                               0.15
# 860464                                               0.09
# 860465                                               0.09
#
#         seller.seller_reputation.transactions.ratings.positive  \
# 0                                                    0.48
# 4                                                    0.97
# 8                                                    0.94
# 12                                                   1.00
# 16                                                   0.98
# ...                                                   ...
# 860461                                               0.81
# 860462                                               0.90
# 860463                                               0.79
# 860464                                               0.87
# 860465                                               0.83
#
#         seller.seller_reputation.transactions.ratings.neutral  \
# 0                                                    0.00
# 4                                                    0.02
# 8                                                    0.02
# 12                                                   0.00
# 16                                                   0.01
# ...                                                   ...
# 860461                                               0.19
# 860462                                               0.03
# 860463                                               0.06
# 860464                                               0.04
# 860465                                               0.08
#
#         seller.seller_reputation.transactions.completed  \
# 0                                                  24.0
# 4                                                1919.0
# 8                                               18709.0
# 12                                               1012.0
# 16                                               4317.0
# ...                                                 ...
# 860461                                            139.0
# 860462                                          15443.0
# 860463                                            989.0
# 860464                                           7810.0
# 860465                                           2275.0
#
#        seller.seller_reputation.power_seller_status  \
# 0                                              None
# 4                                          platinum
# 8                                          platinum
# 12                                             gold
# 16                                         platinum
# ...                                             ...
# 860461                                         None
# 860462                                     platinum
# 860463                                         None
# 860464                                     platinum
# 860465                                     platinum
#
#         seller.seller_reputation.metrics.claims.rate  \
# 0                                             0.0000
# 4                                             0.0048
# 8                                             0.0099
# 12                                            0.0266
# 16                                            0.0066
# ...                                              ...
# 860461                                        0.0931
# 860462                                        0.0202
# 860463                                        0.0199
# 860464                                        0.0171
# 860465                                        0.0155
#
#         seller.seller_reputation.metrics.claims.value  \
# 0                                                 1.0
# 4                                                 3.0
# 8                                                93.0
# 12                                               11.0
# 16                                               14.0
# ...                                               ...
# 860461                                           15.0
# 860462                                          109.0
# 860463                                           21.0
# 860464                                           83.0
# 860465                                           12.0
#
#        seller.seller_reputation.metrics.claims.period  \
# 0                                            365 days
# 4                                             60 days
# 8                                             60 days
# 12                                            60 days
# 16                                            60 days
# ...                                               ...
# 860461                                       365 days
# 860462                                        60 days
# 860463                                        60 days
# 860464                                        60 days
# 860465                                        60 days
#
#         seller.seller_reputation.metrics.delayed_handling_time.rate  \
# 0                                                  0.1200
# 4                                                  0.0000
# 8                                                  0.0007
# 12                                                 0.0110
# 16                                                 0.0020
# ...                                                   ...
# 860461                                             0.0551
# 860462                                             0.0062
# 860463                                             0.0079
# 860464                                             0.0040
# 860465                                             0.0148
#
#         seller.seller_reputation.metrics.delayed_handling_time.value  \
# 0                                                     3.0
# 4                                                     0.0
# 8                                                     7.0
# 12                                                    4.0
# 16                                                    4.0
# ...                                                   ...
# 860461                                                8.0
# 860462                                               32.0
# 860463                                                8.0
# 860464                                               19.0
# 860465                                               11.0
#
#        seller.seller_reputation.metrics.delayed_handling_time.period  \
# 0                                                365 days
# 4                                                 60 days
# 8                                                 60 days
# 12                                                60 days
# 16                                                60 days
# ...                                                   ...
# 860461                                           365 days
# 860462                                            60 days
# 860463                                            60 days
# 860464                                            60 days
# 860465                                            60 days
#
#        seller.seller_reputation.metrics.sales.period  \
# 0                                           365 days
# 4                                            60 days
# 8                                            60 days
# 12                                           60 days
# 16                                           60 days
# ...                                              ...
# 860461                                      365 days
# 860462                                       60 days
# 860463                                       60 days
# 860464                                       60 days
# 860465                                       60 days
#
#         seller.seller_reputation.metrics.sales.completed  \
# 0                                                   24.0
# 4                                                  585.0
# 8                                                 8906.0
# 12                                                 381.0
# 16                                                1949.0
# ...                                                  ...
# 860461                                             139.0
# 860462                                            4980.0
# 860463                                             959.0
# 860464                                            4542.0
# 860465                                             734.0
#
#         seller.seller_reputation.metrics.cancellations.rate  \
# 0                                                  0.0000
# 4                                                  0.0000
# 8                                                  0.0009
# 12                                                 0.0000
# 16                                                 0.0033
# ...                                                   ...
# 860461                                             0.0000
# 860462                                             0.0027
# 860463                                             0.0000
# 860464                                             0.0020
# 860465                                             0.0000
#
#         seller.seller_reputation.metrics.cancellations.value  \
# 0                                                     2.0
# 4                                                     2.0
# 8                                                     9.0
# 12                                                    1.0
# 16                                                    7.0
# ...                                                   ...
# 860461                                                0.0
# 860462                                               15.0
# 860463                                                2.0
# 860464                                               10.0
# 860465                                                2.0
#
#        seller.seller_reputation.metrics.cancellations.period  \
# 0                                                365 days
# 4                                                 60 days
# 8                                                 60 days
# 12                                                60 days
# 16                                                60 days
# ...                                                   ...
# 860461                                           365 days
# 860462                                            60 days
# 860463                                            60 days
# 860464                                            60 days
# 860465                                            60 days
#
#        seller.seller_reputation.level_id      prices.id  \
# 0                                5_green  MLB1811830647
# 4                                5_green  MLB1811696357
# 8                                5_green  MLB1810714496
# 12                               5_green  MLB1811760957
# 16                               5_green  MLB1811384403
# ...                                  ...            ...
# 860461                          2_orange  MLB1874618971
# 860462                           5_green  MLB1874618993
# 860463                           5_green  MLB1874618999
# 860464                           5_green  MLB1874622607
# 860465                           5_green  MLB1874622609
#
#                                             prices.prices  \
# 0       [{'id': '1', 'type': 'standard', 'conditions':...
# 4       [{'id': '1', 'type': 'standard', 'conditions':...
# 8       [{'id': '2', 'type': 'standard', 'conditions':...
# 12      [{'id': '2', 'type': 'standard', 'conditions':...
# 16      [{'id': '3', 'type': 'standard', 'conditions':...
# ...                                                   ...
# 860461  [{'id': '1', 'type': 'standard', 'conditions':...
# 860462  [{'id': '1', 'type': 'standard', 'conditions':...
# 860463  [{'id': '1', 'type': 'standard', 'conditions':...
# 860464  [{'id': '1', 'type': 'standard', 'conditions':...
# 860465  [{'id': '1', 'type': 'standard', 'conditions':...
#
#        prices.presentation.display_currency prices.payment_method_prices  \
# 0                                       BRL                           []
# 4                                       BRL                           []
# 8                                       BRL                           []
# 12                                      BRL                           []
# 16                                      BRL                           []
# ...                                     ...                          ...
# 860461                                  BRL                           []
# 860462                                  BRL                           []
# 860463                                  BRL                           []
# 860464                                  BRL                           []
# 860465                                  BRL                           []
#
#         installments.quantity  installments.amount  installments.rate  \
# 0                        12.0               188.94              13.99
# 4                        12.0                93.25               0.00
# 8                        12.0                72.00               0.00
# 12                       12.0               111.19              13.99
# 16                       12.0               140.00               0.00
# ...                       ...                  ...                ...
# 860461                   12.0               121.63               0.00
# 860462                   12.0               116.63               0.00
# 860463                   12.0               116.65               0.00
# 860464                   12.0               116.58               0.00
# 860465                   12.0               126.26              13.99
#
#        installments.currency_id address.state_id address.state_name  \
# 0                           BRL            BR-MG       Minas Gerais
# 4                           BRL            BR-SP          São Paulo
# 8                           BRL            BR-SP          São Paulo
# 12                          BRL            BR-PR             Paraná
# 16                          BRL            BR-SP          São Paulo
# ...                         ...              ...                ...
# 860461                      BRL            BR-SP          São Paulo
# 860462                      BRL            BR-SP          São Paulo
# 860463                      BRL            BR-SP          São Paulo
# 860464                      BRL            BR-SP          São Paulo
# 860465                      BRL            BR-SP          São Paulo
#
#          address.city_id address.city_name  shipping.free_shipping  \
# 0       TUxCQ0lUQTQ3ZGVk           Itajubá                    True
# 4               BR-SP-44         São Paulo                    True
# 8               BR-SP-44         São Paulo                    True
# 12      TUxCQ0NVUjYyZmY1          Curitiba                    True
# 16              BR-SP-44         São Paulo                    True
# ...                  ...               ...                     ...
# 860461          BR-SP-46   Taboão da Serra                    True
# 860462          BR-SP-46   Taboão da Serra                    True
# 860463          BR-SP-46   Taboão da Serra                    True
# 860464          BR-SP-46   Taboão da Serra                    True
# 860465          BR-SP-46   Taboão da Serra                    True
#
#        shipping.mode                                    shipping.tags  \
# 0                me2                      ['mandatory_free_shipping']
# 4                me2  ['mandatory_free_shipping', 'self_service_out']
# 8                me2   ['self_service_in', 'mandatory_free_shipping']
# 12               me2                      ['mandatory_free_shipping']
# 16               me2   ['self_service_in', 'mandatory_free_shipping']
# ...              ...                                              ...
# 860461           me2                      ['mandatory_free_shipping']
# 860462           me2  ['self_service_out', 'mandatory_free_shipping']
# 860463           me2  ['self_service_out', 'mandatory_free_shipping']
# 860464           me2   ['self_service_in', 'mandatory_free_shipping']
# 860465           me2   ['self_service_in', 'mandatory_free_shipping']
#
#        shipping.logistic_type  shipping.store_pick_up  seller_address.id  \
# 0                    drop_off                   False                NaN
# 4                 xd_drop_off                   False                NaN
# 8               cross_docking                   False                NaN
# 12                   drop_off                   False                NaN
# 16                xd_drop_off                   False                NaN
# ...                       ...                     ...                ...
# 860461            xd_drop_off                   False                NaN
# 860462          cross_docking                   False                NaN
# 860463            xd_drop_off                   False                NaN
# 860464          cross_docking                   False                NaN
# 860465               drop_off                   False                NaN
#
#         seller_address.comment  seller_address.address_line  \
# 0                          NaN                          NaN
# 4                          NaN                          NaN
# 8                          NaN                          NaN
# 12                         NaN                          NaN
# 16                         NaN                          NaN
# ...                        ...                          ...
# 860461                     NaN                          NaN
# 860462                     NaN                          NaN
# 860463                     NaN                          NaN
# 860464                     NaN                          NaN
# 860465                     NaN                          NaN
#
#         seller_address.zip_code seller_address.country.id  \
# 0                           NaN                        BR
# 4                           NaN                        BR
# 8                           NaN                        BR
# 12                          NaN                        BR
# 16                          NaN                        BR
# ...                         ...                       ...
# 860461                      NaN                        BR
# 860462                      NaN                        BR
# 860463                      NaN                        BR
# 860464                      NaN                        BR
# 860465                      NaN                        BR
#
#        seller_address.country.name seller_address.state.id  \
# 0                           Brasil                   BR-MG
# 4                           Brasil                   BR-SP
# 8                           Brasil                   BR-SP
# 12                          Brasil                   BR-PR
# 16                          Brasil                   BR-SP
# ...                            ...                     ...
# 860461                      Brasil                   BR-SP
# 860462                      Brasil                   BR-SP
# 860463                      Brasil                   BR-SP
# 860464                      Brasil                   BR-SP
# 860465                      Brasil                   BR-SP
#
#        seller_address.state.name seller_address.city.id  \
# 0                   Minas Gerais       TUxCQ0lUQTQ3ZGVk
# 4                      São Paulo               BR-SP-44
# 8                      São Paulo               BR-SP-44
# 12                        Paraná       TUxCQ0NVUjYyZmY1
# 16                     São Paulo               BR-SP-44
# ...                          ...                    ...
# 860461                 São Paulo               BR-SP-46
# 860462                 São Paulo               BR-SP-46
# 860463                 São Paulo               BR-SP-46
# 860464                 São Paulo               BR-SP-46
# 860465                 São Paulo               BR-SP-46
#
#        seller_address.city.name  seller_address.latitude  \
# 0                       Itajubá                      NaN
# 4                     São Paulo                      NaN
# 8                     São Paulo                      NaN
# 12                     Curitiba                      NaN
# 16                    São Paulo                      NaN
# ...                         ...                      ...
# 860461          Taboão da Serra                      NaN
# 860462          Taboão da Serra                      NaN
# 860463          Taboão da Serra                      NaN
# 860464          Taboão da Serra                      NaN
# 860465          Taboão da Serra                      NaN
#
#         seller_address.longitude  differential_pricing.id  \
# 0                            NaN                      NaN
# 4                            NaN               33580182.0
# 8                            NaN               33580182.0
# 12                           NaN                      NaN
# 16                           NaN               33580182.0
# ...                          ...                      ...
# 860461                       NaN               33580182.0
# 860462                       NaN               33580182.0
# 860463                       NaN               33580182.0
# 860464                       NaN               33580182.0
# 860465                       NaN                      NaN
#
#        seller.eshop.nick_name  seller.eshop.eshop_rubro  \
# 0                        None                       NaN
# 4                        None                       NaN
# 8             EVB ELETRÔNICOS                       NaN
# 12            ALUK IMPORTADOS                       NaN
# 16                       None                       NaN
# ...                       ...                       ...
# 860461                   None                       NaN
# 860462                   None                       NaN
# 860463                   None                       NaN
# 860464                   None                       NaN
# 860465                   None                       NaN
#
#         seller.eshop.eshop_id seller.eshop.eshop_locations  \
# 0                         NaN                         None
# 4                         NaN                         None
# 8                    365518.0                           []
# 12                   449830.0                           []
# 16                        NaN                         None
# ...                       ...                          ...
# 860461                    NaN                         None
# 860462                    NaN                         None
# 860463                    NaN                         None
# 860464                    NaN                         None
# 860465                    NaN                         None
#
#        seller.eshop.site_id  \
# 0                      None
# 4                      None
# 8                       MLB
# 12                      MLB
# 16                     None
# ...                     ...
# 860461                 None
# 860462                 None
# 860463                 None
# 860464                 None
# 860465                 None
#
#                               seller.eshop.eshop_logo_url  \
# 0                                                    None
# 4                                                    None
# 8       http://resources.mlstatic.com/eshops/34743206v...
# 12      http://resources.mlstatic.com/eshops/19588869v...
# 16                                                   None
# ...                                                   ...
# 860461                                               None
# 860462                                               None
# 860463                                               None
# 860464                                               None
# 860465                                               None
#
#         seller.eshop.eshop_status_id  seller.eshop.seller  \
# 0                                NaN                  NaN
# 4                                NaN                  NaN
# 8                                1.0           34743206.0
# 12                               1.0           19588869.0
# 16                               NaN                  NaN
# ...                              ...                  ...
# 860461                           NaN                  NaN
# 860462                           NaN                  NaN
# 860463                           NaN                  NaN
# 860464                           NaN                  NaN
# 860465                           NaN                  NaN
#
#         seller.eshop.eshop_experience  \
# 0                                 NaN
# 4                                 NaN
# 8                                 0.0
# 12                                0.0
# 16                                NaN
# ...                               ...
# 860461                            NaN
# 860462                            NaN
# 860463                            NaN
# 860464                            NaN
# 860465                            NaN
#
#         seller.seller_reputation.metrics.claims.excluded.real_rate  \
# 0                                                     NaN
# 4                                                     NaN
# 8                                                     NaN
# 12                                                    NaN
# 16                                                    NaN
# ...                                                   ...
# 860461                                                NaN
# 860462                                                NaN
# 860463                                                NaN
# 860464                                                NaN
# 860465                                                NaN
#
#         seller.seller_reputation.metrics.claims.excluded.real_value  \
# 0                                                     NaN
# 4                                                     NaN
# 8                                                     NaN
# 12                                                    NaN
# 16                                                    NaN
# ...                                                   ...
# 860461                                                NaN
# 860462                                                NaN
# 860463                                                NaN
# 860464                                                NaN
# 860465                                                NaN
#
#         seller.seller_reputation.metrics.delayed_handling_time.excluded.real_rate  \
# 0                                                     NaN
# 4                                                     NaN
# 8                                                     NaN
# 12                                                    NaN
# 16                                                    NaN
# ...                                                   ...
# 860461                                                NaN
# 860462                                                NaN
# 860463                                                NaN
# 860464                                                NaN
# 860465                                                NaN
#
#         seller.seller_reputation.metrics.delayed_handling_time.excluded.real_value  \
# 0                                                     NaN
# 4                                                     NaN
# 8                                                     NaN
# 12                                                    NaN
# 16                                                    NaN
# ...                                                   ...
# 860461                                                NaN
# 860462                                                NaN
# 860463                                                NaN
# 860464                                                NaN
# 860465                                                NaN
#
#         seller.seller_reputation.metrics.cancellations.excluded.real_rate  \
# 0                                                     NaN
# 4                                                     NaN
# 8                                                     NaN
# 12                                                    NaN
# 16                                                    NaN
# ...                                                   ...
# 860461                                                NaN
# 860462                                                NaN
# 860463                                                NaN
# 860464                                                NaN
# 860465                                                NaN
#
#         seller.seller_reputation.metrics.cancellations.excluded.real_value  \
# 0                                                     NaN
# 4                                                     NaN
# 8                                                     NaN
# 12                                                    NaN
# 16                                                    NaN
# ...                                                   ...
# 860461                                                NaN
# 860462                                                NaN
# 860463                                                NaN
# 860464                                                NaN
# 860465                                                NaN
#
#        seller.seller_reputation.protection_end_date  \
# 0                                              None
# 4                                              None
# 8                                              None
# 12                                             None
# 16                                             None
# ...                                             ...
# 860461                                         None
# 860462                                         None
# 860463                                         None
# 860464                                         None
# 860465                                         None
#
#        seller.seller_reputation.real_level  installments date_file  \
# 0                                     None           NaN  20210301
# 4                                     None           NaN  20210301
# 8                                     None           NaN  20210301
# 12                                    None           NaN  20210301
# 16                                    None           NaN  20210301
# ...                                    ...           ...       ...
# 860461                                None           NaN  20210505
# 860462                                None           NaN  20210505
# 860463                                None           NaN  20210505
# 860464                                None           NaN  20210505
# 860465                                None           NaN  20210505
#
#                                category_file seller.car_dealer_logo  \
# 0       MLB1051/dados-20210301-MLB1051-0.csv                   None
# 4       MLB1051/dados-20210301-MLB1051-0.csv                   None
# 8       MLB1051/dados-20210301-MLB1051-0.csv                   None
# 12      MLB1051/dados-20210301-MLB1051-0.csv                   None
# 16      MLB1051/dados-20210301-MLB1051-0.csv                   None
# ...                                      ...                    ...
# 860461  MLB1055/dados-20210505-MLB1055-0.csv                   None
# ...
# 0                standard       2021-03-01T22:58:54Z   Samsung
# 4                standard       2021-03-01T20:23:26Z    Xiaomi
# 8                standard       2021-03-01T13:34:52Z   Samsung
# 12               standard       2021-03-01T23:21:54Z    Xiaomi
# 16               standard       2021-03-01T18:31:15Z    Xiaomi
# ...                   ...                        ...       ...
# 860461           standard       2021-05-04T20:17:04Z  Motorola
# 860462           standard       2021-05-04T20:17:06Z  Motorola
# 860463           standard       2021-05-04T20:17:08Z  Motorola
# 860464           standard       2021-05-04T20:17:00Z  Motorola
# 860465           standard       2021-05-04T20:17:01Z  Motorola
#
#          Modelo de GPU Condição do item     Linha               Modelo  \
# 0         Mali-G72 MP3             Novo  Galaxy M                  M31
# 4       PowerVR GE8320             Novo     Redmi            9 (India)
# 8       PowerVR GE8320             Novo  Galaxy A            A10s Duos
# 12          Adreno 610             Novo     Redmi               Note 8
# 16         Adreno A618             Novo     Redmi  Note 9 Pro (48 Mpx)
# ...                ...              ...       ...                  ...
# 860461      Adreno 610             Novo    Moto G                  G10
# 860462      Adreno 610             Novo    Moto G                  G10
# 860463      Adreno 610             Novo    Moto G                  G10
# 860464      Adreno 610             Novo    Moto G         G10 Dual SIM
# 860465      Adreno 610             Novo    Moto G                  G10
#
#             Modelo do processador   Peso Modelo detalhado  \
# 0                     Exynos 9611  191 g             None
# 4              MediaTek Helio G35  194 g             None
# 8       MediaTek MT6762 Helio P22  168 g             None
# 12                 Snapdragon 665  190 g             None
# 16                Snapdragon 720G  209 g             None
# ...                           ...    ...              ...
# 860461             Snapdragon 662  198 g            P9001
# 860462             Snapdragon 662  198 g            P9001
# 860463             Snapdragon 662  198 g            P9001
# 860464             Snapdragon 662  198 g            P9001
# 860465             Snapdragon 662  198 g            P9001
#
#                                          Marca compatível Linha compatível  \
# 0                                                    None             None
# 4                                                    None             None
# 8                                                    None             None
# 12                                                   None             None
# 16                                                   None             None
# ...                                                   ...              ...
# 860461  J500, SM-J500M, SM-J500M/DS SM-J500F, SM-J500G...         Galaxy J
# 860462  J500, SM-J500M, SM-J500M/DS SM-J500F, SM-J500G...         Galaxy J
# 860463  J500, SM-J500M, SM-J500M/DS SM-J500F, SM-J500G...         Galaxy J
# 860464  J500, SM-J500M, SM-J500M/DS SM-J500F, SM-J500G...         Galaxy J
# 860465  J500, SM-J500M, SM-J500M/DS SM-J500F, SM-J500G...         Galaxy J
#
#                                         Modelo compatível Marca da Capa  \
# 0                                                    None          None
# 4                                                    None          None
# 8                                                    None          None
# 12                                                   None          None
# 16                                                   None          None
# ...                                                   ...           ...
# 860461  J500, SM-J500M, SM-J500M/DS SM-J500F, SM-J500G...      Genérica
# 860462  J500, SM-J500M, SM-J500M/DS SM-J500F, SM-J500G...      Genérica
# 860463  J500, SM-J500M, SM-J500M/DS SM-J500F, SM-J500G...      Genérica
# 860464  J500, SM-J500M, SM-J500M/DS SM-J500F, SM-J500G...      Genérica
# 860465  J500, SM-J500M, SM-J500M/DS SM-J500F, SM-J500G...      Genérica
#
#        Marca de Celular   Linha do celular  \
# 0                  None               None
# 4                  None               None
# 8                  None               None
# 12                 None               None
# 16                 None               None
# ...                 ...                ...
# 860461           iPhone  Moto G4 e G4 Plus
# 860462           iPhone  Moto G4 e G4 Plus
# 860463           iPhone  Moto G4 e G4 Plus
# 860464           iPhone  Moto G4 e G4 Plus
# 860465           iPhone  Moto G4 e G4 Plus
#
#                                         Modelo de Celular  \
# 0                                                    None
# 4                                                    None
# 8                                                    None
# 12                                                   None
# 16                                                   None
# ...                                                   ...
# 860461  iPhone X /niPhone 6 6s/n/xa0iPhone 7/niPhone 7...
# 860462  iPhone X /niPhone 6 6s/n/xa0iPhone 7/niPhone 7...
# 860463  iPhone X /niPhone 6 6s/n/xa0iPhone 7/niPhone 7...
# 860464  iPhone X /niPhone 6 6s/n/xa0iPhone 7/niPhone 7...
# 860465  iPhone X /niPhone 6 6s/n/xa0iPhone 7/niPhone 7...
#
#                                            Modelo da Capa Marca do cabo  \
# 0                                                    None          None
# 4                                                    None          None
# 8                                                    None          None
# 12                                                   None          None
# 16                                                   None          None
# ...                                                   ...           ...
# 860461  iPhone X /niPhone 6 6s/n/xa0iPhone 7/niPhone 7...     Importado
# 860462  iPhone X /niPhone 6 6s/n/xa0iPhone 7/niPhone 7...     Importado
# 860463  iPhone X /niPhone 6 6s/n/xa0iPhone 7/niPhone 7...     Importado
# 860464  iPhone X /niPhone 6 6s/n/xa0iPhone 7/niPhone 7...     Importado
# 860465  iPhone X /niPhone 6 6s/n/xa0iPhone 7/niPhone 7...     Importado
#
#        Comprimento do cabo  Modelo do cabo Marca da película  \
# 0                     None            None              None
# 4                     None            None              None
# 8                     None            None              None
# 12                    None            None              None
# 16                    None            None              None
# ...                    ...             ...               ...
# 860461                 1 m  USB IPHONE 2.0           Zlianda
# 860462                 1 m  USB IPHONE 2.0           Zlianda
# 860463                 1 m  USB IPHONE 2.0           Zlianda
# 860464                 1 m  USB IPHONE 2.0           Zlianda
# 860465                 1 m  USB IPHONE 2.0           Zlianda
#
#        Modelo da película Unidades por embalagem Marca do celular  \
# 0                    None                   None             None
# 4                    None                   None             None
# 8                    None                   None             None
# 12                   None                   None             None
# 16                   None                   None             None
# ...                   ...                    ...              ...
# 860461                N/A                      1          G4 PLUS
# 860462                N/A                      1          G4 PLUS
# 860463                N/A                      1          G4 PLUS
# 860464                N/A                      1          G4 PLUS
# 860465                N/A                      1          G4 PLUS
#
#            Modelo do celular Modelo alfanumérico Comprimento da embalagem  \
# 0                       None                None                     None
# 4                       None                None                     None
# 8                       None                None                     None
# 12                      None                None                     None
# 16                      None                None                     None
# ...                      ...                 ...                      ...
# 860461  Xt1640 Xt1626 Xt1622               A1858                     3 cm
# 860462  Xt1640 Xt1626 Xt1622               A1858                     3 cm
# 860463  Xt1640 Xt1626 Xt1622               A1858                     3 cm
# 860464  Xt1640 Xt1626 Xt1622               A1858                     3 cm
# 860465  Xt1640 Xt1626 Xt1622               A1858                     3 cm
#
#        Peso da embalagem Marca da bateria Modelo da bateria Comprimento  \
# 0                   None             None              None        None
# 4                   None             None              None        None
# 8                   None             None              None        None
# 12                  None             None              None        None
# 16                  None             None              None        None
# ...                  ...              ...               ...         ...
# 860461             100 g          General               N/A      4.3 cm
# 860462             100 g          General               N/A      4.3 cm
# 860463             100 g          General               N/A      4.3 cm
# 860464             100 g          General               N/A      4.3 cm
# 860465             100 g          General               N/A      4.3 cm
#
#        Marca celular Potência Marca de celular compatível  \
# 0               None     None                        None
# 4               None     None                        None
# 8               None     None                        None
# 12              None     None                        None
# 16              None     None                        None
# ...              ...      ...                         ...
# 860461      Motorola      N/A                    Motorola
# 860462      Motorola      N/A                    Motorola
# 860463      Motorola      N/A                    Motorola
# 860464      Motorola      N/A                    Motorola
# 860465      Motorola      N/A                    Motorola
#
#        Comprimento da pulseira Potência de entrada Potência de saída  \
# 0                         None                None              None
# 4                         None                None              None
# 8                         None                None              None
# 12                        None                None              None
# 16                        None                None              None
# ...                        ...                 ...               ...
# 860461                   20 cm                 0 W               0 W
# 860462                   20 cm                 0 W               0 W
# 860463                   20 cm                 0 W               0 W
# 860464                   20 cm                 0 W               0 W
# 860465                   20 cm                 0 W               0 W
#
#        Potência mínima Potência máxima Permite Operação de App Marca do carro  \
# 0                 None            None                    None           None
# 4                 None            None                    None           None
# 8                 None            None                    None           None
# 12                None            None                    None           None
# 16                None            None                    None           None
# ...                ...             ...                     ...            ...
# 860461             5 W           200 W                     Sim     Volkswagen
# 860462             5 W           200 W                     Sim     Volkswagen
# 860463             5 W           200 W                     Sim     Volkswagen
# 860464             5 W           200 W                     Sim     Volkswagen
# 860465             5 W           200 W                     Sim     Volkswagen
#
#        Unidades por kit                            Modelo do carro  \
# 0                  None                                       None
# 4                  None                                       None
# 8                  None                                       None
# 12                 None                                       None
# 16                 None                                       None
# ...                 ...                                        ...
# 860461                1  Novo Polo Virtus Up Gol Voyage Saveiro G7
# 860462                1  Novo Polo Virtus Up Gol Voyage Saveiro G7
# 860463                1  Novo Polo Virtus Up Gol Voyage Saveiro G7
# 860464                1  Novo Polo Virtus Up Gol Voyage Saveiro G7
# 860465                1  Novo Polo Virtus Up Gol Voyage Saveiro G7
#
#        Modelo celular Comprimento do punho Comprimento da lâmina  \
# 0                None                 None                  None
# 4                None                 None                  None
# 8                None                 None                  None
# 12               None                 None                  None
# 16               None                 None                  None
# ...               ...                  ...                   ...
# 860461         xt 305               4.7 cm                 47 cm
# 860462         xt 305               4.7 cm                 47 cm
# 860463         xt 305               4.7 cm                 47 cm
# 860464         xt 305               4.7 cm                 47 cm
# 860465         xt 305               4.7 cm                 47 cm
#
#        Modelo de TV compatível  \
# 0                         None
# 4                         None
# 8                         None
# 12                        None
# 16                        None
# ...                        ...
# 860461
# 860462
# 860463
# 860464
# 860465
#
#                                               title_upper memory ram_memory  \
# 0        SAMSUNG GALAXY M31 DUAL SIM 128 GB AZUL 6 GB RAM    128          6
# 4       XIAOMI REDMI 9 (INDIA) DUAL SIM 64 GB SKY BLUE...     64          4
# 8       SAMSUNG GALAXY A10S DUAL SIM 32 GB VERMELHO 2 ...     32          2
# 12      XIAOMI REDMI NOTE 8 DUAL SIM 64 GB SPACE BLACK...     64          4
# 16      XIAOMI REDMI NOTE 9 PRO (48 MPX) DUAL SIM 128 ...    128          4
# ...                                                   ...    ...        ...
# 860461  SMARTPHONE MOTOROLA MOTO G10 XT2127-2 DUAL SIM...   None       None
# 860462  SMARTPHONE MOTOROLA MOTO G10 XT2127-2 DUAL SIM...   None       None
# 860463  CELULAR MOTOROLA MOTO G10 XT2127-2 DUAL SIM 64...   None       None
# 860464  SMARTPHONE MOTOROLA MOTO G10 DUAL SIM 64GB CIN...   None       None
# 860465  SMARTPHONE MOTOROLA MOTO G10 XT2127-2 DUAL SIM...   None       None
#
#        classificacao         modelo_upper
# 0            CELULAR                  M31
# 4            CELULAR            9 (INDIA)
# 8            CELULAR            A10S DUOS
# 12           CELULAR               NOTE 8
# 16           CELULAR  NOTE 9 PRO (48 MPX)
# ...              ...                  ...
# 860461       CELULAR                  G10
# 860462       CELULAR                  G10
# 860463       CELULAR                  G10
# 860464       CELULAR         G10 DUAL SIM
# 860465       CELULAR                  G10
#
# [128991 rows x 160 columns]

# %%
words = ['4G', 'DUAL SIM', '5G', 'AIRPODS','WATCH','TELA', 'NIKE' ]

def word_cleanup(word):
    for ex in words:
        word = word.replace(ex, '')
    return word.strip()

# %%
df_marcas_classificacao['modelo_upper'] = df_marcas_classificacao['modelo_upper'].apply(word_cleanup)
# Out:
# C:\Users\eloah.noguchi\Miniconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
csv = df_marcas_filtradas.to_csv(r'C:\Users\eloah.noguchi\Downloads\df_marca_filtradas.csv', index=0)

# %%
list_select = ['id','title_upper','price','condition','Linha','Marca','Modelo de GPU','Modelo','Modelo do processador','Peso','category_file','address.city_name','address.city_id','address.state_name','address.state_id'	,'category_id', 'permalink', 'memory', 'ram_memory', 'prices.prices.type', 'prices.prices.last_updated', 'modelo_upper', 'classificacao']

# %%
df_marcas_filtradas = df_marcas_classificacao[list_select]

# %%
df_marcas_filtradas
# Out:
#                    id                                        title_upper  \
# 0       MLB1811830647   SAMSUNG GALAXY M31 DUAL SIM 128 GB AZUL 6 GB RAM
# 4       MLB1811696357  XIAOMI REDMI 9 (INDIA) DUAL SIM 64 GB SKY BLUE...
# 8       MLB1810714496  SAMSUNG GALAXY A10S DUAL SIM 32 GB VERMELHO 2 ...
# 12      MLB1811760957  XIAOMI REDMI NOTE 8 DUAL SIM 64 GB SPACE BLACK...
# 16      MLB1811384403  XIAOMI REDMI NOTE 9 PRO (48 MPX) DUAL SIM 128 ...
# ...               ...                                                ...
# 860461  MLB1874618971  SMARTPHONE MOTOROLA MOTO G10 XT2127-2 DUAL SIM...
# 860462  MLB1874618993  SMARTPHONE MOTOROLA MOTO G10 XT2127-2 DUAL SIM...
# 860463  MLB1874618999  CELULAR MOTOROLA MOTO G10 XT2127-2 DUAL SIM 64...
# 860464  MLB1874622607  SMARTPHONE MOTOROLA MOTO G10 DUAL SIM 64GB CIN...
# 860465  MLB1874622609  SMARTPHONE MOTOROLA MOTO G10 XT2127-2 DUAL SIM...
#
#           price condition     Linha     Marca   Modelo de GPU  \
# 0       1989.00       new  Galaxy M   Samsung    Mali-G72 MP3
# 4       1119.00       new     Redmi    Xiaomi  PowerVR GE8320
# 8        864.00       new  Galaxy A   Samsung  PowerVR GE8320
# 12      1170.50       new     Redmi    Xiaomi      Adreno 610
# 16      1680.00       new     Redmi    Xiaomi     Adreno A618
# ...         ...       ...       ...       ...             ...
# 860461  1459.50       new    Moto G  Motorola      Adreno 610
# 860462  1399.50       new    Moto G  Motorola      Adreno 610
# 860463  1399.85       new    Moto G  Motorola      Adreno 610
# 860464  1399.00       new    Moto G  Motorola      Adreno 610
# 860465  1329.15       new    Moto G  Motorola      Adreno 610
#
#                      Modelo      Modelo do processador   Peso  \
# 0                       M31                Exynos 9611  191 g
# 4                 9 (India)         MediaTek Helio G35  194 g
# 8                 A10s Duos  MediaTek MT6762 Helio P22  168 g
# 12                   Note 8             Snapdragon 665  190 g
# 16      Note 9 Pro (48 Mpx)            Snapdragon 720G  209 g
# ...                     ...                        ...    ...
# 860461                  G10             Snapdragon 662  198 g
# 860462                  G10             Snapdragon 662  198 g
# 860463                  G10             Snapdragon 662  198 g
# 860464         G10 Dual SIM             Snapdragon 662  198 g
# 860465                  G10             Snapdragon 662  198 g
#
#                                category_file address.city_name  \
# 0       MLB1051/dados-20210301-MLB1051-0.csv           Itajubá
# 4       MLB1051/dados-20210301-MLB1051-0.csv         São Paulo
# 8       MLB1051/dados-20210301-MLB1051-0.csv         São Paulo
# 12      MLB1051/dados-20210301-MLB1051-0.csv          Curitiba
# 16      MLB1051/dados-20210301-MLB1051-0.csv         São Paulo
# ...                                      ...               ...
# 860461  MLB1055/dados-20210505-MLB1055-0.csv   Taboão da Serra
# 860462  MLB1055/dados-20210505-MLB1055-0.csv   Taboão da Serra
# 860463  MLB1055/dados-20210505-MLB1055-0.csv   Taboão da Serra
# 860464  MLB1055/dados-20210505-MLB1055-0.csv   Taboão da Serra
# 860465  MLB1055/dados-20210505-MLB1055-0.csv   Taboão da Serra
#
#          address.city_id address.state_name address.state_id category_id  \
# 0       TUxCQ0lUQTQ3ZGVk       Minas Gerais            BR-MG     MLB1055
# 4               BR-SP-44          São Paulo            BR-SP     MLB1055
# 8               BR-SP-44          São Paulo            BR-SP     MLB1055
# 12      TUxCQ0NVUjYyZmY1             Paraná            BR-PR     MLB1055
# 16              BR-SP-44          São Paulo            BR-SP     MLB1055
# ...                  ...                ...              ...         ...
# 860461          BR-SP-46          São Paulo            BR-SP     MLB1055
# 860462          BR-SP-46          São Paulo            BR-SP     MLB1055
# 860463          BR-SP-46          São Paulo            BR-SP     MLB1055
# 860464          BR-SP-46          São Paulo            BR-SP     MLB1055
# 860465          BR-SP-46          São Paulo            BR-SP     MLB1055
#
#                                                 permalink memory ram_memory  \
# 0       https://www.mercadolivre.com.br/samsung-galaxy...    128          6
# 4       https://www.mercadolivre.com.br/xiaomi-redmi-9...     64          4
# 8       https://www.mercadolivre.com.br/samsung-galaxy...     32          2
# 12      https://www.mercadolivre.com.br/xiaomi-redmi-n...     64          4
# 16      https://www.mercadolivre.com.br/xiaomi-redmi-n...    128          4
# ...                                                   ...    ...        ...
# 860461  https://produto.mercadolivre.com.br/MLB-187461...   None       None
# 860462  https://produto.mercadolivre.com.br/MLB-187461...   None       None
# 860463  https://produto.mercadolivre.com.br/MLB-187461...   None       None
# 860464  https://produto.mercadolivre.com.br/MLB-187462...   None       None
# 860465  https://produto.mercadolivre.com.br/MLB-187462...   None       None
#
#        prices.prices.type prices.prices.last_updated         modelo_upper  \
# 0                standard       2021-03-01T22:58:54Z                  M31
# 4                standard       2021-03-01T20:23:26Z            9 (INDIA)
# 8                standard       2021-03-01T13:34:52Z            A10S DUOS
# 12               standard       2021-03-01T23:21:54Z               NOTE 8
# 16               standard       2021-03-01T18:31:15Z  NOTE 9 PRO (48 MPX)
# ...                   ...                        ...                  ...
# 860461           standard       2021-05-04T20:17:04Z                  G10
# 860462           standard       2021-05-04T20:17:06Z                  G10
# 860463           standard       2021-05-04T20:17:08Z                  G10
# 860464           standard       2021-05-04T20:17:00Z                  G10
# 860465           standard       2021-05-04T20:17:01Z                  G10
#
#        classificacao
# 0            CELULAR
# 4            CELULAR
# 8            CELULAR
# 12           CELULAR
# 16           CELULAR
# ...              ...
# 860461       CELULAR
# 860462       CELULAR
# 860463       CELULAR
# 860464       CELULAR
# 860465       CELULAR
#
# [128991 rows x 23 columns]
