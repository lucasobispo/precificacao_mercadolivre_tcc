# %%
import boto3 as boto3
import pandas as pd
import pyarrow.parquet as pq
import s3fs
from io import BytesIO

# %%
ACCESS_KEY = 'ASIASEOMK5IL466JLI6R'
SECRET_KEY = 'bohg7nMVG6Xj7WGNw+8DeNK8129zAMhKbzzaO9Bj'
AWS_SESSION_TOKEN = '...'

# %%
def pd_read_s3_parquet(key, bucket, s3_client=None, **args):
    if s3_client is None:
        s3_client = boto3.client('s3', aws_access_key_id=ACCESS_KEY,aws_secret_access_key=SECRET_KEY,aws_session_token=AWS_SESSION_TOKEN)
    obj = s3_client.get_object(Bucket=bucket, Key=key)
    return pd.read_parquet(BytesIO(obj['Body'].read()), **args)

# %%
base_juntada_atributes =  pd_read_s3_parquet("20210423/dados-caracteristicas-9000.parquet","dados-transformados-mercadolivre")

# %%
base_juntada_atributes
# Out:
#                id      descricao Marca Linha Modelo Memória interna  \
# 0   MLB1783701943        AfriPro  None  None   None            None
# 0   MLB1783701943        AfriPro  None  None   None            None
# 0   MLB1783702042        AfriPro  None  None   None            None
# 0   MLB1783702189  Universal car  None  None   None            None
# 0   MLB1783702189           SanM  None  None   None            None
# ..            ...            ...   ...   ...    ...             ...
# 0   MLB1783885026             LG  None  None   None            None
# 0   MLB1783885026             LG  None  None   None            None
# 0   MLB1783886086             LG  None  None   None            None
# 0   MLB1783886086             LG  None  None   None            None
# 0   MLB1783886224             LG  None  None   None            None
#
#    Memória RAM Com ranhura para cartão de memória Tipos de cartão de memória  \
# ...
