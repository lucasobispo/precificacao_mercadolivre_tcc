# %%
import boto3 as boto3
import pandas as pd
import pyarrow.parquet as pq
import s3fs
from io import BytesIO

# %%
pd.set_option('display.max_columns', 500)

# %%
ACCESS_KEY = 'ASIASEOMK5IL566ZFYXS'
SECRET_KEY = 'XtNtjeoHqSjMDuj6O/1R/+HnBQGGC9spYHearKEE'
AWS_SESSION_TOKEN = '...'

# %%
def pd_read_s3_parquet(key, bucket, s3_client=None, **args):
    if s3_client is None:
        s3_client = boto3.client('s3', aws_access_key_id=ACCESS_KEY,aws_secret_access_key=SECRET_KEY,aws_session_token=AWS_SESSION_TOKEN)
    obj = s3_client.get_object(Bucket=bucket, Key=key)
    return pd.read_parquet(BytesIO(obj['Body'].read()), **args)

# %%
def pd_read_s3_csv(my_bucket,my_file):
    s3 = boto3.client('s3', aws_access_key_id=ACCESS_KEY,
                      aws_secret_access_key=SECRET_KEY,
                      aws_session_token=AWS_SESSION_TOKEN)

    obj = s3.get_object(Bucket=my_bucket, Key= my_file)
    body =  pd.read_csv(obj['Body'])
    df = pd.DataFrame(body)
    return df

# %%
base_juntada_atributes =  pd_read_s3_parquet("20210505/dados-limpos-20210505.parquet","dados-transformados-mercadolivre")

# %%
#base_juntada_atributes.groupby('permalink').id.count().sort_values()
base_juntada_atributes
# Out:
#        Unnamed: 0             id site_id  \
# 0               0  MLB1783483197     MLB
# 1               0  MLB1783483197     MLB
# 2               0  MLB1783483197     MLB
# 3               0  MLB1783483197     MLB
# 4               1  MLB1784404609     MLB
# ...           ...            ...     ...
# 64926          69  MLB1791879583     MLB
# 64927          70  MLB1791880014     MLB
# 64928          71  MLB1791881723     MLB
# 64929          72  MLB1791882073     MLB
# 64930          73  MLB1791882761     MLB
#
#                                                              title   price  \
# 0      Xiaomi Redmi 9 (global) Dual Sim 64 Gb Carbon Grey 4 Gb Ram  1259.0
# 1      Xiaomi Redmi 9 (global) Dual Sim 64 Gb Carbon Grey 4 Gb Ram  1259.0
# 2      Xiaomi Redmi 9 (global) Dual Sim 64 Gb Carbon Grey 4 Gb Ram  1259.0
# 3      Xiaomi Redmi 9 (global) Dual Sim 64 Gb Carbon Grey 4 Gb Ram  1259.0
# 4         Xiaomi Redmi Note 8 Dual Sim 64 Gb Neptune Blue 4 Gb Ram  1355.0
# ...

# %% [markdown]
# #Tratamento das colunas

# %%
#join com o 'id'
#base_juntada_atributes = pd.merge(base_juntada, df_atributes, on=["id"])

# %%
#base_juntada_atributes = pd.read_csv(r"C:\Users\eloah.noguchi\Downloads\out\out.csv")

# %%
from flatten_json import (check_if_numbers_are_consecutive, cli, flatten,
                          flatten_preserve_lists, unflatten, unflatten_list)
import pandas as pd
import urllib.request as urllib2
import json
import re

base_juntada_atributes['title_upper'] = base_juntada_atributes['title'].str.upper()

GB_search = []
GBRAM_search = []
for values in base_juntada_atributes['title_upper']:
    
    if re.findall(r"(\d+) GB(?!RAM|\.).*", values):
        GB_search.append(*re.findall(r"(\d+) GB(?!RAM|\.).*", values))
    else:
        GB_search.append(None)
    
    if re.findall(r"(\d+) GB RAM", values):
        GBRAM_search.append(*re.findall(r"(\d+) GB RAM", values))
    else:
        GBRAM_search.append(None)
    
#     print(values)
#     print(*GB_search)
base_juntada_atributes['memory'] = GB_search
base_juntada_atributes['ram_memory'] = GBRAM_search

# %%
# pd.set_option('display.max_rows', base_juntada_atributes.shape[0]+1)

# %%
base_juntada_atributes.isnull().mean().sort_values(ascending = False)
# Out:
# seller_address.address_line    1.0
# seller_address.zip_code        1.0
# seller.car_dealer_logo         1.0
# installments                   1.0
# seller.eshop.eshop_rubro       1.0
#                               ...
# address.city_id                0.0
# address.state_name             0.0
# address.state_id               0.0
# Modelo de GPU                  0.0
# Unnamed: 0                     0.0
# Length: 144, dtype: float64

# %%
list_select = ['id','Linha','Marca','Modelo de GPU','title_upper','Modelo','Modelo do processador','Peso','price','category_file','address.city_name','address.city_id','address.state_name','address.state_id'	,'condition','category_id', 'permalink', 'memory', 'ram_memory', 'prices.prices.type', 'prices.prices.last_updated']

# %%
#Função de calssificação do titulo
def classifica_titulo(titulo):
    for key in keywords:
        if titulo.upper().find(key) > -1:
            return key
    return 'CELULAR'

# %%
#Remoção das linhas duplicadas
lista_marcas = ['Apple','Xiaomi', 'Realme', 'Motorola', 'Samsung', 'Sony', 'LG', 'Huawei']
without_duplicates = base_juntada_atributes.drop_duplicates()
without_duplicates_permalink =  without_duplicates.drop_duplicates(subset = 'permalink', keep = 'first')
df_marcas= without_duplicates_permalink[without_duplicates_permalink.Marca.isin(lista_marcas)]

# %%
keywords=['CAPA', 'RELOGIO', 'CAPINHA', 'XIAOMI POCO M3', 'MOTO G9 PLUS DUAL SIM 128 GB AZUL-ÍNDIGO 4 GB RAM', 'WATCH']
df_marcas['classificacao']=df_marcas['title_upper'].apply(classifica_titulo)
# Out:
# C:\Users\eloah.noguchi\Miniconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_marcas_classificacao['modelo_upper'] = df_marcas_classificacao['Modelo'].str.upper()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-e7380aba2ad7> in <module>
# ----> 1 df_marcas_classificacao['modelo_upper'] = df_marcas_classificacao['Modelo'].str.upper()
#
# NameError: name 'df_marcas_classificacao' is not defined

# %%
 df_marcas[df_marcas.id == 'MLB1783732395']
# Out:
#      Unnamed: 0             id site_id  \
# 440         125  MLB1783732395     MLB
#
#                                         title  price  sale_price currency_id  \
# 440  Smartphone Motorola Moto E4 Plus Usado.   600.0         NaN         BRL
#
#      available_quantity  sold_quantity buying_mode listing_type_id  \
# 440                   1              0  buy_it_now    gold_special
#
#                     stop_time condition  \
# 440  2041-01-27T04:00:00.000Z      used
#
#                                                                                          permalink  \
# 440  https://produto.mercadolivre.com.br/MLB-1783732395-smartphone-motorola-moto-e4-plus-usado-_JM
#
#                                                            thumbnail  \
# 440  http://mlb-s2-p.mlstatic.com/635816-MLB44771315132_022021-I.jpg
#
#                      thumbnail_id  accepts_mercadopago  \
# 440  635816-MLB44771315132_022021                 True
#
# ...

# %% [markdown]
# TESTES

# %%
base_juntada_atributes_filtrada = df_marcas[list_select]

# %%
base_modelo = base_juntada_atributes_filtrada[base_juntada_atributes_filtrada.price > 1000]

# %%
count_result = base_juntada_atributes_filtrada[base_juntada_atributes_filtrada.price > 1000].groupby(['Marca']).size()
count_result.sort_values(ascending = False)
# Out:
# Marca
# Apple       3725
# Xiaomi      1730
# Samsung      857
# Motorola     320
# Realme       108
# dtype: int64

# %%
base_modelo = base_modelo.drop('category_id',1)
base_modelo = base_modelo.drop('title_upper',1)
base_modelo = base_modelo.drop('category_file',1)
base_modelo = base_modelo.drop(['address.city_name','address.city_id','address.state_name'],1)

# %%
base_modelo['Peso'] = base_modelo['Peso'].str.replace(' g', "")
base_modelo['Peso'] = base_modelo['Peso'].str.replace(' kg', "")
base_modelo['Peso'] = pd.to_numeric(base_modelo['Peso'])

# %%
csv = base_modelo.to_csv(r'C:\Users\eloah.noguchi\Downloads\base_modelo.csv', index=0)

# %%
encoded_columns = pd.get_dummies(base_modelo[['Linha','Marca','Modelo de GPU','Modelo','Modelo do processador','address.state_id','condition']])
data = base_modelo.join(encoded_columns).drop(['Linha','Marca','Modelo de GPU','Modelo','Modelo do processador','address.state_id','condition'], axis=1)

# %%
data
# Out:
#                   id   Peso   price  \
# 0      MLB1783483197  198.0  1259.0
# 4      MLB1784404609  190.0  1355.0
# 8      MLB1784407781  190.0  1355.0
# 12     MLB1783919650  215.0  1749.0
# 16     MLB1784453284  190.0  1355.0
# ...              ...    ...     ...
# 64922  MLB1791878901  138.0  1399.0
# 64923  MLB1791879173  143.0  1250.0
# 64924  MLB1791879174  196.0  2900.0
# 64928  MLB1791881723  155.0  1600.0
# 64929  MLB1791882073  177.0  1500.0
#
#                                                permalink memory ram_memory  \
# 0      https://www.mercadolivre.com.br/xiaomi-redmi-9...     64          4
# 4      https://www.mercadolivre.com.br/xiaomi-redmi-n...     64          4
# 8      https://www.mercadolivre.com.br/xiaomi-redmi-n...     64          4
# 12     https://www.mercadolivre.com.br/xiaomi-poco-x3...     64          6
# 16     https://www.mercadolivre.com.br/xiaomi-redmi-n...     64          4
# ...

# %%
# Total de registros distintos por id
unico = base_juntada_atributes['permalink'].nunique()

# %%
unico
# Out:
# 57356

# %%
#Configuração para aumentar a largura do df
pd.set_option('display.max_colwidth', 300)

# %%
#groupby pelo campo permalink, ordenando pela qtd
without_duplicates_permalink.groupby('permalink').id.count().sort_values()
# Out:
# permalink
# https://produto.mercadolivre.com.br/MLB-1783445480-carto-de-memoria-alta-capacidade-512gb-_JM                          1
# https://produto.mercadolivre.com.br/MLB-1790761814-desk-dobravel-do-silicone-do-suporte-universal-do-telefone-m-_JM    1
# https://produto.mercadolivre.com.br/MLB-1790761817-2pcs-universal-bicicleta-bicicleta-guiador-montagem-titular-_JM     1
# https://produto.mercadolivre.com.br/MLB-1790761818-ph-universal-do-entalhe-do-cd-da-montagem-do-berco-do-carro-_JM     1
# https://produto.mercadolivre.com.br/MLB-1790761819-2pcs-gub-aluminio-mtb-bicicletamoto-titular-do-telefone-mo-_JM      1
#                                                                                                                       ..
# https://produto.mercadolivre.com.br/MLB-1787212728-capa-requintada-disney-mickey-samsung-s9plus-s8plus-s7-s10-_JM      1
# https://produto.mercadolivre.com.br/MLB-1787212733-capa-para-iphone-xxsxs-maxxr-na-moda-pikachu-_JM                    1
# ...

# %%
# quantidade por condição
df_marcas.groupby('condition').condition.count() #retirar distintos
# Out:
# condition
# new              6025
# not_specified       3
# used             7148
# Name: condition, dtype: int64

# %%
df_marcas.isnull().mean()
# Out:
# Unnamed: 0       0.000000
# id               0.000000
# site_id          0.000000
# title            0.000000
# price            0.000000
#                    ...
# Potência         0.375607
# title_upper      0.000000
# memory           0.709548
# ram_memory       0.856330
# classificacao    0.000000
# Length: 145, dtype: float64

# %%
# quantidade por linha
df_marcas.groupby('Linha').Linha.count().sort_values() #retirar distintos
# Out:
# Linha
# Moto G7 G8 One Hyper       1
# Nexus                      1
# No                         1
# Nord Series                1
# Note                       1
#                         ...
# Moto G                   615
# Galaxy J                 621
# Galaxy A                 777
# Redmi                   2022
# iPhone                  4555
# Name: Linha, Length: 406, dtype: int64

# %%
# quantidade por marca
df_marcas.groupby('Marca').Marca.count().sort_values()
# Out:
# Marca
# Realme       116
# Motorola    1680
# Xiaomi      3016
# Samsung     3328
# Apple       5036
# Name: Marca, dtype: int64

# %%
# quantidade por estado
df_marcas.groupby('address.state_id').size().sort_values()
# Out:
# address.state_id
# BR-RR       6
# BR-AC       9
# BR-TO      19
# BR-RO      20
# BR-SE      24
# BR-AL      26
# BR-AM      38
# BR-PI      40
# BR-PB      40
# BR-PA      56
# BR-RN      56
# BR-MS      84
# BR-MT      88
# BR-PE      95
# BR-MA      98
# BR-CE      98
# BR-ES     123
# BR-DF     155
# BR-BA     318
# BR-RS     340
# BR-SC     412
# BR-GO     641
# BR-PR     836
# BR-RJ     855
# BR-MG    1023
# BR-SP    7676
# dtype: int64

# %%
# quantidade por modelo
df_marcas.groupby('Modelo').Modelo.count().sort_values()
# Out:
# Modelo
# zb634kl                1
# G950FD                 1
# GALAXY                 1
# GATE4800BT             1
# GT- 18552b             1
#                     ...
# iPhone 12 Pro Max    366
# iPhone 8 Plus        376
# iPhone 11            442
# iPhone 7             444
# iPhone 11 Pro Max    652
# Name: Modelo, Length: 1270, dtype: int64

# %%
(df_marcas['Modelo do processador'].str.find("Tek") > -1).value_counts()
# Out:
# False    11185
# True      1991
# Name: Modelo do processador, dtype: int64

# %%
#procurar por uma string no titulo do anuncio
lst_celular = []

for values in df_marcas['title_upper']:
    print(values)
    if values.find("CAPA") > -1:
        print("ok")
        lst_celular.append(0)
    elif df_marcas[df_marcas['title_upper'].str.upper().str.find("RELOGIO") > -1]:
        lst_celular.append(0)
    elif df_marcas[df_marcas['title_upper'].str.upper().str.find("CAPINHA") > -1]:
        lst_celular.append(0)
    elif df_marcas[df_marcas['title_upper'].str.upper().str.find("PELICULA") > -1]:
        lst_celular.append(0)
    else:
        lst_celular.append(1)

df_marcas['celular'] = lst_celular
# Out:
# XIAOMI REDMI 9 (GLOBAL) DUAL SIM 64 GB CARBON GREY 4 GB RAM
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-9ccb91167941> in <module>
#       7         print("ok")
#       8         lst_celular.append(0)
# ----> 9     elif df_marcas[df_marcas['title_upper'].str.upper().str.find("RELOGIO") > -1]:
#      10         lst_celular.append(0)
#      11     elif df_marcas[df_marcas['title_upper'].str.upper().str.find("CAPINHA") > -1]:
#
# ~\Miniconda3\envs\dev\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1325     def __nonzero__(self):
#    1326         raise ValueError(
# -> 1327             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1328             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1329         )
#
# ...

# %%
df_marcas['Modelo'].value_counts()
# Out:
# iPhone 11 Pro Max                                                                                                                                                       652
# iPhone 7                                                                                                                                                                444
# iPhone 11                                                                                                                                                               442
# iPhone 8 Plus                                                                                                                                                           376
# iPhone 12 Pro Max                                                                                                                                                       366
# ...

# %%
df_marcas['classificacao']=df_marcas['title_upper'].apply(classifica_titulo)
# Out:
# C:\Users\eloah.noguchi\Miniconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_marcas.classificacao.value_counts()
# Out:
# CELULAR                                              12277
# CAPA                                                   687
# CAPINHA                                                 98
# XIAOMI POCO M3                                          89
# RELOGIO                                                 18
# MOTO G9 PLUS DUAL SIM 128 GB AZUL-ÍNDIGO 4 GB RAM        7
# Name: classificacao, dtype: int64

# %%
words = ['4G', 'DUAL SIM', '5G']*100

def word_cleanup(word):
    for ex in words:
        word = word.replace(ex, '')
    return word.strip()

# %%
s_test = pd.Series(['10 5G', '11 DUAL SIM', '9 4G']*10000)

# %%
# %timeit s_test.apply(word_cleanup)
# Out:
# 2.76 s ± 890 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
